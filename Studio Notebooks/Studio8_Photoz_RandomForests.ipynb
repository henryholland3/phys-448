# %% [markdown]
# ### Random Forests and Photo-zs
#
# In this notebook, we use Random Forests to estimate photometric redshifts starting from observations of galaxy magnitudes in six different photometric bands (u, g, r, i, z, y). It accompanies Chapter 6 of the book (1 of 4).
#
# Copyright: Viviana Acquaviva (2023); see also other data credits below.
#
# Modification by Julieta Gruszko (2025)
#
# License: [BSD-3-clause](https://opensource.org/license/bsd-3-clause/)
#
# Essentially, we try to reproduce/improve upon the results of [this paper](https://arxiv.org/abs/1903.08174), for which the data are public and available [here](http://d-scholarship.pitt.edu/36064/). Additionally, we are very grateful to Jeff Newman for his expert advice.

# %% [markdown]
# >Henry Holland, Peter Chtcheprov, Ben Tonnesen

# %%
# !pip install astropy #installs tools for astronomy in python
# Out:
# Requirement already satisfied: astropy in /opt/anaconda3/envs/PHYS448/lib/python3.13/site-packages (7.1.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/PHYS448/lib/python3.13/site-packages (from astropy) (2.3.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /opt/anaconda3/envs/PHYS448/lib/python3.13/site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /opt/anaconda3/envs/PHYS448/lib/python3.13/site-packages (from astropy) (0.2025.10.6.0.35.25)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/anaconda3/envs/PHYS448/lib/python3.13/site-packages (from astropy) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /opt/anaconda3/envs/PHYS448/lib/python3.13/site-packages (from astropy) (25.0)

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 100)


font = {'size'   : 16}
matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
matplotlib.rcParams.update({'figure.autolayout': False})
matplotlib.rcParams['figure.dpi'] = 300

# %%
from sklearn import metrics
from sklearn.model_selection import cross_validate, KFold, cross_val_predict, GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor #new!

# %%
import astropy

from astropy.io import fits

#fits stands for Flexible Image Transport System; it's a format that allows one to store images and summary data

# %% [markdown]
# #### Data import

# %% [markdown]
# We can read the data into a data frame using pandas:

# %%
with fits.open('../Data/DEEP2_uniq_Terapix_Subaru_v1.fits') as data:
    a = np.array(data[1].data, copy=True)
    result = a.byteswap().view(a.dtype.newbyteorder())
    df = pd.DataFrame(result)

# %%
df.columns
# Out:
# Index(['objno_deep2', 'ra_deep2', 'dec_deep2', 'magb', 'magr', 'magi', 'pgal',
#        'sfd_ebv', 'class', 'subclass', 'objname', 'maskname', 'slitname',
#        'date', 'mjd', 'z_raw', 'zhelio', 'z_err', 'rchi2', 'dof', 'vdisp',
#        'vdisp_err', 'zquality', 'egsflags', 'comment', 'm_b', 'ub_0',
#        'ra_cfhtls', 'dec_cfhtls', 'u', 'g', 'r', 'i', 'i2', 'z', 'uerr',
#        'gerr', 'rerr', 'ierr', 'i2err', 'zerr', 'u_apercor', 'g_apercor',
#        'r_apercor', 'i_apercor', 'i2_apercor', 'z_apercor', 'uerr_aper',
#        'gerr_aper', 'rerr_aper', 'ierr_aper', 'i2err_aper', 'zerr_aper',
#        'uerr_apercor', 'gerr_apercor', 'rerr_apercor', 'ierr_apercor',
#        'i2err_apercor', 'zerr_apercor', 'r_radius_arcsec', 'u(sexflag)',
#        'g(sexflag)', 'r(sexflag)', 'i(sexflag)', 'i2(sexflag)', 'z(sexflag)',
#        'flag_cfhtls', 'cfhtls_source', 'ra_subaru', 'dec_subaru', 'y', 'yerr',
#        'y_apercor', 'yerr_aper', 'yerr_apercor', 'y(sexflag)',
#        'y_radius_arcsec', 'subaru_source'],
#       dtype='object')

# %%
df.head()
# Out:
#    objno_deep2    ra_deep2  dec_deep2       magb       magr       magi  \
# 0     11001673  213.868704  51.956445  23.487745  23.143082  22.582092
# 1     11001699  213.810471  51.942316  22.067692  20.034674  19.545080
# 2     11001770  213.848431  51.948876  24.144438  24.103180  24.020006
# 3     11001800  213.831758  51.952548  25.336836  23.508480  23.081087
# 4     11001860  213.832550  51.954174  24.382738  23.401484  22.572845
#
#        pgal   sfd_ebv      class subclass      objname maskname slitname  \
# 0  1.000000  0.010943        b''      b''  b'11001673'  b'1101'   b'000'
# 1  3.000000  0.011014  b'GALAXY'      b''  b'11001699'  b'1100'     b'7'
# 2  3.000000  0.010856  b'GALAXY'      b''  b'11001770'  b'1101'   b'003'
# 3  0.509809  0.010823  b'GALAXY'      b''  b'11001800'  b'1100'   b'004'
# 4  3.000000  0.010827  b'GALAXY'      b''  b'11001860'  b'1101'    b'10'
#
#             date           mjd     z_raw    zhelio       z_err     rchi2  \
# 0  b'2003-05-06'  52765.457031  1.115297  1.115261  999.900024  0.630934
# 1  b'2003-05-03'  52762.441406  0.290641  0.290608    0.000043  1.178153
# 2  b'2003-05-06'  52765.457031  0.605779  0.605744   -5.000000  1.047260
# 3  b'2003-05-03'  52762.441406  1.306830  1.306796   -5.000000  1.014062
# 4  b'2003-05-06'  52765.457031  0.957705  0.957669    0.000099  1.039979
#
#       dof       vdisp   vdisp_err  zquality  egsflags  \
# 0    57.0  999.900024  999.900024         2  16777216
# 1  5901.0  166.334991   49.481255         4  16777216
# 2  5318.0  184.860001  195.000000         1  16777216
# 3  5788.0    0.000000    0.000000         1  16777216
# 4  5952.0  109.394997   17.208755         4  16777216
#
#                        comment         m_b      ub_0   ra_cfhtls  dec_cfhtls  \
# 0  b'bext, bcol, possible OII' -999.000000 -999.0000  213.868620   51.956434
# 1                          b''  -19.228701    1.1295  213.810138   51.942348
# 2                          b'' -999.000000 -999.0000  213.848409   51.948865
# 3                          b'' -999.000000 -999.0000  213.831785   51.952539
# 4                          b''  -20.083200    0.7524  213.832540   51.954167
#
#            u          g          r          i    i2          z    uerr  \
# 0  23.529039  23.393115  23.148170  22.854212 -99.0  22.162377  0.0678
# 1  30.123756  28.298480  18.540350  99.000000 -99.0  99.000000  0.0000
# 2  24.294289  24.399293  24.413366  23.398456 -99.0  24.157690  0.1646
# 3  26.363821  24.530998  23.559140  23.065110 -99.0  22.737333  0.9609
# 4  24.571406  24.023086  23.493832  22.691404 -99.0  22.387428  0.1924
#
#      gerr    rerr     ierr  i2err     zerr  u_apercor  g_apercor  r_apercor  \
# 0  0.0400  0.0382   0.0678  -99.0   0.0623  23.543491  23.430495  23.100311
# 1  0.0000  0.0014  99.0000  -99.0  99.0000  30.848978  28.989668  19.027422
# 2  0.1383  0.2306   0.1867  -99.0   0.4558  24.324670  24.273606  24.150319
# 3  0.1344  0.0648   0.0997  -99.0   0.1110  99.000000  24.804309  23.636544
# 4  0.0874  0.0651   0.0715  -99.0   0.0850  24.362068  24.136913  23.490342
#
#    i_apercor  i2_apercor  z_apercor  uerr_aper  gerr_aper  rerr_aper  \
# 0  22.768970       -99.0  22.223810     0.0542     0.0323     0.0279
# 1  99.000000       -99.0  99.000000     0.0000     0.0000     0.0028
# 2  23.446252       -99.0  23.574236     0.1146     0.0870     0.1242
# 3  23.009222       -99.0  22.689591    99.0000     0.1077     0.0426
# 4  22.777181       -99.0  22.319676     0.1002     0.0615     0.0420
#
#    ierr_aper  i2err_aper  zerr_aper  uerr_apercor  gerr_apercor  rerr_apercor  \
# 0     0.0466       -99.0     0.0536      0.039631      0.041359      0.039777
# 1    99.0000       -99.0    99.0000      0.029567      0.030353      0.027558
# 2     0.1309       -99.0     0.1793      0.111127      0.130134      0.123620
# 3     0.0568       -99.0     0.0661     99.000000      0.046521      0.041142
# 4     0.0473       -99.0     0.0508      0.050326      0.053198      0.052364
#
#    ierr_apercor  i2err_apercor  zerr_apercor  r_radius_arcsec  u(sexflag)  \
# 0      0.046863          -99.0      0.043833         0.581804           3
# 1     99.000000          -99.0     99.000000         0.824625          19
# 2      0.117813          -99.0      0.101059         0.728119           0
# 3      0.054297          -99.0      0.053818         0.549061           0
# 4      0.058492          -99.0      0.053587         0.595684           0
#
#    g(sexflag)  r(sexflag)  i(sexflag)  i2(sexflag)  z(sexflag)  flag_cfhtls  \
# 0           3           3           3          -99           3            0
# 1          19          19           3          -99           3          244
# 2           0           0           0          -99           0            0
# 3           0           0           0          -99           0            0
# 4           0           0           0          -99           0            0
#
#    cfhtls_source   ra_subaru  dec_subaru          y       yerr  y_apercor  \
# 0              1  213.868626   51.956443  21.869627   0.060918  21.926356
# 1              1  213.810455   51.942321  18.757229   0.005813  18.811085
# 2              1  -99.000000  -99.000000 -99.000000 -99.000000 -99.000000
# 3              1  213.831766   51.952544  22.404269   0.088970  22.535600
# 4              1  213.832574   51.954175  22.242717   0.070760  22.100980
#
#    yerr_aper  yerr_apercor  y(sexflag)  y_radius_arcsec  subaru_source
# 0   0.041955      0.141778         3.0         0.656514              1
# 1   0.004386      0.050987         3.0         0.744269              1
# 2 -99.000000    -99.000000       -99.0       -99.000000            -99
# 3   0.053497      0.094733         0.0         0.455820              1
# 4   0.033256      0.073067         0.0         0.442022              1

# %%
df.shape
# Out:
# (23822, 78)

# %% [markdown]
# We can select the columns we want, corresponding to the brightness of the galaxies in the six bands of interest.

# %%
features = df[['u_apercor', 'g_apercor', 'r_apercor', 'i_apercor', 'z_apercor','y_apercor']]

# %% [markdown]
# The target property is the redshift. For this catalog, spectroscopic (more precise) redshifts, to use as the ground truth, are available in the column "zhelio".

# %%
target = df['zhelio']

# %%
features.head(10)
# Out:
#    u_apercor  g_apercor  r_apercor  i_apercor  z_apercor  y_apercor
# 0  23.543491  23.430495  23.100311  22.768970  22.223810  21.926356
# 1  30.848978  28.989668  19.027422  99.000000  99.000000  18.811085
# 2  24.324670  24.273606  24.150319  23.446252  23.574236 -99.000000
# 3  99.000000  24.804309  23.636544  23.009222  22.689591  22.535600
# 4  24.362068  24.136913  23.490342  22.777181  22.319676  22.100980
# 5  23.552186  23.420734  23.010863  22.550723  22.277656  21.860866
# 6  23.983330  24.104438  23.461145  23.359428  22.929944  22.690175
# 7  24.665840  24.408938  23.544115  23.155140  22.706477  22.894691
# 8  23.518039  22.746858  21.571629  20.645176  20.428926  20.306110
# 9  22.755723  21.915841  21.393365  21.148952  21.052236  20.830114

# %%
target.head(10)
# Out:
# 0    1.115261
# 1    0.290608
# 2    0.605744
# 3    1.306796
# 4    0.957669
# 5    0.909043
# 6    0.502974
# 7    0.649839
# 8    0.679440
# 9    0.074078
# Name: zhelio, dtype: float32

# %% [markdown]
# ### Ok, we are now ready to run our first Random Forest model!

# %% [markdown]
# To get an idea of what we are shooting for, we can look at a figure in the paper:
#
#  ![Performance of photometric redshift reconstruction](./Photoz_RF_CFHTLS_Deep.png)

# %% [markdown]
# In the figure above, $\sigma_{NMAD}$ is the normalized median absolute deviation of the residual vector, and $\eta$  is the fraction of outliers, defined as those objects for which (z_true - z_est)/(1+z_true) > 0.15.
#
# To be fair, we are working with DEEP2/3 data, so our range is slightly different.

# %%
model = RandomForestRegressor()

# %%
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# We begin by establishing a benchmark (note: it takes a little time; ~35 secs on my machine).

# %%
scores = cross_validate(model,features,target, cv = KFold(n_splits=5, shuffle=True, random_state=10), return_train_score=True)

# %%
scores
# Out:
# {'fit_time': array([7.37617612, 7.33080602, 7.34848189, 7.36858511, 7.31190896]),
#  'score_time': array([0.08821106, 0.08874702, 0.08536816, 0.08404875, 0.08500195]),
#  'test_score': array([0.29984097, 0.31261684, 0.3096058 , 0.30217965, 0.31963757]),
#  'train_score': array([0.87361862, 0.8791274 , 0.87670494, 0.8770294 , 0.87452142])}

# %% [markdown]
# As a reminder, the scores are the R2 score at this point.

# %%
np.mean(scores['test_score'])
# Out:
# np.float64(0.3087761646897677)

# %%
np.mean(scores['train_score'])
# Out:
# np.float64(0.8762003547238446)

# %% [markdown]
# Looks like we have a severe high variance issue! Let's also check the predictions and plot them against the true values.

# %%
ypred = cross_val_predict(model,features,target, cv = KFold(n_splits=5, shuffle=True, random_state=10))

# %%
plt.scatter(target,ypred, s = 2, c = 'royalblue')
plt.xlabel('True (spectroscopic) z', fontsize=14)
plt.ylabel('Predicted z',fontsize=14)
plt.axis('square')
plt.xlim(0,3)
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %% [markdown]
# ### Question: Does it look like the one of the paper? How is the performance looking (quick qualitative assessment is fine!)?

# %% [markdown]
# >No. It does not look like it. The graph we get has data spread out much more. The variance is very high.

# %% [markdown]
# It's also interesting to look at the distribution of the predicted values, to see how they always tend to produce a narrower distribution. Why?
#
# This is a characteristic of tree-based methods; examples with very low/high values of the target are "bunched up" with others that have higher/lower values, so the predictions tend to be over-estimated for low values of the target variables and under-estimated for high values. You can usually see this trend in scatter plots as well!

# %%
plt.hist(target,bins=50,density=False,alpha=0.5, range = (0,3), label = 'True');
plt.hist(ypred,bins=50,density=False,alpha=0.5, range = (0,3), color = 'g', label = 'Predicted');
plt.legend(fontsize=14);

# %% [markdown]
# Ok, we are now ready to calculate the outlier fraction:

# %%
len(np.where(np.abs(target-ypred)>0.15*(1+target))[0])/len(target)
# Out:
# 0.25673746956594745

# %% [markdown]
# And NMAD

# %%
1.48*np.median(np.abs(target-ypred)/(1 + target)) 
#The 1.48 is there because for a Gaussian distribution, this becomes the standard deviation
# Out:
# np.float64(0.07516557567584572)

# %% [markdown]
# ### Clearly, we are very far from the paper's performance :(
#
# ### Because we have a pretty severe high variance issue, we could perform some parameter optimization, shown below.
#
# ### However, it turns out it doesn't help, and that our real issue here is that we skipped the data cleaning/pre-processing step! We have a lot of low-quality data mixed in, which is confusing our training steps. Skip down to the "RESUME HERE" label to do the data cleaning and then optimize the Random Forest.

# %% [markdown]
# ### Skip this section in studio:
#
# But it's provided for reference in case you want to look at the steps we followed.

# %% [markdown]
# We can start by making the data set a bit smaller, as we have seen that timings were already challenging in simple k-fold CV.

# %%
np.random.seed(20)
sel = np.random.choice(range(len(ypred)), 5000, replace = False) #sample without replacement

# %%
len(np.unique(sel))
# Out:
# 5000

# %% [markdown]
# And we create our new smaller data set.

# %%
seld = features.loc[sel,:]
selt = target[sel]

# %% [markdown]
# It is good practice to ensure that the performance on the smaller set remains similar to the one obtained on the entire data set, which means that the change in size will not significantly affect the optimization process.

# %%
littlescores = cross_validate(model,seld,selt, cv = KFold(n_splits=5, shuffle=True, random_state=10), return_train_score=True)

# %%
littlescores['test_score'].mean(), littlescores['train_score'].mean()
# Out:
# (np.float64(0.27762715338769406), np.float64(0.8763722031531694))

# %% [markdown]
# ### We are now ready to optimize hyperparameters - what should we choose?

# %% [markdown]
# #### Tree Parameters
#
# Some useful parameters associated to a tree are:
#
# -  The minimum number of instances in a leaf node;
#
# -  The minimum number of instances required in a split node;
#
# - The maximum depth of tree;
#
# -  The criterion chosen to decide whether a split is "worth it", expressed in terms of information gain.
#
#
# #### Randomization Parameters
#
# Here we find:
#
# - The number of k < n features that are used in building trees;
#
# - The re-sampling (boostrap) of the data set (T or F).
#
#
# #### Forest Parameters
#
# The number of trees in the forest (n_estimators) can be adjusted, with the general understanding that more trees are better, but at some point performance will plateau, so one can find the trade-off between having more trees and lower runtime.

# %% [markdown]
# We can visualize them like this:

# %%
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Here below is a possible set; we can run a grid search to look for the best model.

# %% [markdown]
# - min_impurity_decrease
#
# - number of trees
#
# - max_leaf_nodes
#
# - min_samples_split
#
# - max_features

# %%
#Takes a few minutes

parameters = {'min_impurity_decrease':[0.1, 0.5, 0.0], \
              'max_features':[None,4,2], 'n_estimators':[50, 100, 200], 'min_samples_split': [10,20,100], 
              'max_leaf_nodes':[None, 100, 200]}
nmodels = np.prod([len(el) for el in parameters.values()])
model = GridSearchCV(RandomForestRegressor(), parameters, cv = KFold(n_splits=5, shuffle=True), \
                     verbose = 2, n_jobs = 4, return_train_score=True)
model.fit(seld,selt)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   2.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   2.4s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   2.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   2.3s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   2.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.6s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.6s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.6s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.7s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.7s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   1.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   1.9s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   1.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   1.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.4s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   1.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.7s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.7s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.6s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.7s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   1.7s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END max_features=None, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.3s
# ...
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=100, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=50; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.1, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=50; total time=   0.0s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=100; total time=   0.1s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.5, min_samples_split=100, n_estimators=200; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=50; total time=   0.2s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.3s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.3s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.3s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.3s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END max_features=2, max_leaf_nodes=200, min_impurity_decrease=0.0, min_samples_split=100, n_estimators=200; total time=   0.7s
# Best params, best score: 0.2927 {'max_features': 4, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_split': 20, 'n_estimators': 200}

# %% [markdown]
# As usual, we save the results in a data frame, and look at the best models to build some intution.

# %%
scores = pd.DataFrame(model.cv_results_)
scoresCV = scores[['params','mean_test_score','std_test_score','mean_train_score']].sort_values(by = 'mean_test_score', \
                                                    ascending = False)

# %%
scoresCV
# Out:
#                                                                                                   params  \
# 104  {'max_features': 4, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_split': 2...
# 182  {'max_features': 2, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_split': 1...
# 101  {'max_features': 4, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_split': 1...
# 185  {'max_features': 2, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_split': 2...
# 100  {'max_features': 4, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_split': 1...
# ..                                                                                                   ...
# 147  {'max_features': 4, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.5, 'min_samples_split': 20...
# 91   {'max_features': 4, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 1...
# 60   {'max_features': None, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.1, 'min_samples_split':...
# 177  {'max_features': 2, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.5, 'min_samples_split': 1...
# 111  {'max_features': 4, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'min_samples_split': 20...
#
#      mean_test_score  std_test_score  mean_train_score
# 104         0.292657        0.016949          0.653066
# 182         0.292574        0.019601          0.726311
# 101         0.292502        0.019366          0.752082
# 185         0.290587        0.015664          0.623627
# 100         0.290252        0.023158          0.749492
# ..               ...             ...               ...
# 147        -0.000091        0.000093         -0.000004
# 91         -0.000091        0.000082         -0.000003
# 60         -0.000092        0.000068         -0.000008
# 177        -0.000094        0.000082         -0.000010
# 111        -0.000133        0.000125         -0.000016
#
# [243 rows x 4 columns]

# %% [markdown]
# ### And the verdict is....

# %% [markdown]
# We have NOT improved the test scores.

# %% [markdown]
# ### <font color='red'> RESUME HERE </font>
#
#
# After noting that our issue is so severe that it's hard to attribute it to an optimization or chooice of algorithm issue, we need to look more carefully at data cleaning and/or imputing (something, in fact, that should be the first step in our pipeline!)
#
# In my case, it was time to write to the authors of the paper, who told me exactly how they selected the data that went into making the learning set.
#
# We needed to retain some additional columns to be used in the selection process.

# %%
mags = df[['u_apercor', 'g_apercor', 'r_apercor', 'i_apercor', 'z_apercor','y_apercor','subaru_source','cfhtls_source','zquality']]

# %%
mags.head()
# Out:
#    u_apercor  g_apercor  r_apercor  i_apercor  z_apercor  y_apercor  \
# 0  23.543491  23.430495  23.100311  22.768970  22.223810  21.926356
# 1  30.848978  28.989668  19.027422  99.000000  99.000000  18.811085
# 2  24.324670  24.273606  24.150319  23.446252  23.574236 -99.000000
# 3  99.000000  24.804309  23.636544  23.009222  22.689591  22.535600
# 4  24.362068  24.136913  23.490342  22.777181  22.319676  22.100980
#
#    subaru_source  cfhtls_source  zquality
# 0              1              1         2
# 1              1              1         4
# 2            -99              1         1
# 3              1              1         1
# 4              1              1         4

# %%
mags.shape
# Out:
# (23822, 9)

# %%
#redshift quality - only use objects with high-quality spectroscopic redshift measurements

mags = mags[mags['zquality'] >= 3]

mags.shape
# Out:
# (16857, 9)

# %%
#select objects with cfhtls deep photometric data 

mags = mags[mags['cfhtls_source'] == 0]

mags.shape
# Out:
# (10671, 9)

# %% [markdown]
# Unavailable measurements are marked by -99 or 99 (while typical values are around 20-25). We also get rid of data with missing measurements.

# %%
mags = mags[mags > -10].dropna()

# %%
mags.shape
# Out:
# (6371, 9)

# %%
mags = mags[mags < 90].dropna()

# %%
mags.shape
# Out:
# (6307, 9)

# %% [markdown]
# Our final set is made of the six original features and it has 6,307 objects.

# %%
sel_features = mags[['u_apercor', 'g_apercor', 'r_apercor', 'i_apercor', 'z_apercor','y_apercor']]
sel_features.head()
# Out:
#       u_apercor  g_apercor  r_apercor  i_apercor  z_apercor  y_apercor
# 1251  24.244393  23.979583  23.522136  22.911041  22.525773  22.329098
# 1253  24.489104  23.916151  22.923651  21.873752  21.306495  21.251440
# 1261  24.873959  22.973893  21.465850  20.788420  20.462283  20.413696
# 1271  24.529042  24.338631  23.891189  23.206102  22.989344  23.112382
# 1272  23.641180  23.387447  22.975301  22.235199  21.809658  21.559483

# %% [markdown]
# We need, of course, to select the same set on the target vector.

# %%
sel_target = target[sel_features.index]

# %% [markdown]
# To see the power of ensemble methods, let's check how a single (unoptimized) Decision Tree does.

# %%
from sklearn.tree import DecisionTreeRegressor

treescores = cross_validate(DecisionTreeRegressor(random_state = 5),sel_features,sel_target,cv = KFold(n_splits=5, shuffle=True, random_state=10), \
               return_train_score=True)

# %%
print(np.round(np.mean(treescores['test_score']),3), np.round(np.std(treescores['test_score']),3))
# Out:
# 0.526 0.136

# %%
print(np.round(np.mean(treescores['train_score']),3), np.round(np.std(treescores['train_score']),3))
# Out:
# 1.0 0.0

# %% [markdown]
# Let's see how our benchmark model works. Note that for reproducible results we need to fix the random\_state parameter of the Random Forest (which controls the bootstrap process) and the random seed of the cross validation.

# %%
scores = cross_validate(RandomForestRegressor(random_state = 5),sel_features,sel_target,cv = KFold(n_splits=5, shuffle=True, random_state=10), \
               return_train_score=True)

# %%
print(np.round(np.mean(scores['test_score']),3), np.round(np.std(scores['test_score']),3))
# Out:
# 0.746 0.106

# %%
print(np.round(np.mean(scores['train_score']),3), np.round(np.std(scores['train_score']),3))
# Out:
# 0.963 0.005

# %% [markdown]
# ### Questions:
# - How does the Random Forest performance compare to a single Decision Tree performance? Has the ensembling reduced the variance? Has it reduced the generalization error?
# - How many trees are being trained for the RandomForest above?
# - Was there an improvement in the Random Forest scores, relative to before data cleaning? Do you observe high variance?

# %% [markdown]
# >The Random Forest performed better than the single Decision Tree because the single decision tree was too complex and overfit a lot leading to a very high variance.
#
# >The ensembling reduced the variance significantly. The generalization error was reduced slightly.
#
# >100 trees were trained for the RandomForest.
#
# >There was significant improvement in the Random Forest scores relative to before the data cleaning (0.3 -> 0.7). There is variance but it isn't very high.

# %% [markdown]
# We can re-run the optimization process (note that the data set size is limited, so we don't need to make it smaller).
#
# This now takes ~3 minutes, so execute the cell, and then work on answering the question below while it runs.

# %%
#This now takes ~3 minutes. Execute the cell, and then work on answering the question below while it runs.

parameters = {'max_depth':[3, 6, None], \
              'max_features':[None,4,2], 'n_estimators':[50,100,200], 'min_samples_leaf': [1,5,10]}
nmodels = np.prod([len(el) for el in parameters.values()])
model = GridSearchCV(RandomForestRegressor(random_state = 5), parameters, cv = KFold(n_splits=5, shuffle=True, random_state=10), \
                     verbose = 2, n_jobs = 4, return_train_score=True)
model.fit(sel_features,sel_target)

print('Best params, best score:', "{:.4f}".format(model.best_score_), \
      model.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   0.8s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   0.8s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   0.8s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   0.8s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.5s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.5s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.5s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.5s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=3, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   1.0s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   1.0s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.4s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   1.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.5s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   1.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.4s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.4s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.7s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.6s
# [CV] END max_depth=6, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.6s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.6s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   0.6s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.2s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.3s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=6, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   0.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   1.4s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   1.4s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=1, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   1.4s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   2.9s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   2.9s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=5, n_estimators=200; total time=   2.8s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   2.6s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.7s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=50; total time=   0.7s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=10, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   1.3s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   1.3s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   1.3s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   1.3s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=100; total time=   1.3s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   2.6s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   2.6s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   2.6s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   2.6s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=1, n_estimators=200; total time=   2.6s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   1.9s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   1.9s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   1.9s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   2.0s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=5, n_estimators=200; total time=   2.0s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=50; total time=   0.4s
# [CV] END max_depth=None, max_features=4, min_samples_leaf=10, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=1, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=None, max_features=2, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# Best params, best score: 0.7490 {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 200}

# %% [markdown]
# ### Question:
# List the hyperparameters that are being optimized, with a brief description of what each one does and the values tested in the optimization.

# %% [markdown]
# >max_depth: how far the leaf will go
#
# >max_features: how many features the model uses to train
#
# >n_estimators: the number of trees that RandomForest will use
#
# >min_samples_leaf: each leaf must have this number of samples in it

# %%
scores = pd.DataFrame(model.cv_results_)
scoresCV = scores[['params','mean_test_score','std_test_score','mean_train_score']].sort_values(by = 'mean_test_score', \
                                                    ascending = False)
scoresCV
# Out:
#                                                                                     params  \
# 65      {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 200}
# 56   {'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 200}
# 55   {'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 100}
# 64      {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 100}
# 63       {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 50}
# 59   {'max_depth': None, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 200}
# 73      {'max_depth': None, 'max_features': 2, 'min_samples_leaf': 1, 'n_estimators': 100}
# 74      {'max_depth': None, 'max_features': 2, 'min_samples_leaf': 1, 'n_estimators': 200}
# 54    {'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 50}
# 58   {'max_depth': None, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 100}
# 57    {'max_depth': None, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 50}
# 68      {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 5, 'n_estimators': 200}
# 72       {'max_depth': None, 'max_features': 2, 'min_samples_leaf': 1, 'n_estimators': 50}
# 67      {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 5, 'n_estimators': 100}
# 66       {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 5, 'n_estimators': 50}
# 62  {'max_depth': None, 'max_features': None, 'min_samples_leaf': 10, 'n_estimators': 200}
# 61  {'max_depth': None, 'max_features': None, 'min_samples_leaf': 10, 'n_estimators': 100}
# 77      {'max_depth': None, 'max_features': 2, 'min_samples_leaf': 5, 'n_estimators': 200}
# 60   {'max_depth': None, 'max_features': None, 'min_samples_leaf': 10, 'n_estimators': 50}
# 76      {'max_depth': None, 'max_features': 2, 'min_samples_leaf': 5, 'n_estimators': 100}
# 70     {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 10, 'n_estimators': 100}
# 71     {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# 69      {'max_depth': None, 'max_features': 4, 'min_samples_leaf': 10, 'n_estimators': 50}
# 75       {'max_depth': None, 'max_features': 2, 'min_samples_leaf': 5, 'n_estimators': 50}
# 80     {'max_depth': None, 'max_features': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# 79     {'max_depth': None, 'max_features': 2, 'min_samples_leaf': 10, 'n_estimators': 100}
# 78      {'max_depth': None, 'max_features': 2, 'min_samples_leaf': 10, 'n_estimators': 50}
# 35     {'max_depth': 6, 'max_features': None, 'min_samples_leaf': 10, 'n_estimators': 200}
# 34     {'max_depth': 6, 'max_features': None, 'min_samples_leaf': 10, 'n_estimators': 100}
# 33      {'max_depth': 6, 'max_features': None, 'min_samples_leaf': 10, 'n_estimators': 50}
# 32      {'max_depth': 6, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 200}
# 31      {'max_depth': 6, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 100}
# 30       {'max_depth': 6, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 50}
# 44        {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# 29      {'max_depth': 6, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 200}
# 41         {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 5, 'n_estimators': 200}
# 28      {'max_depth': 6, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 100}
# 43        {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 10, 'n_estimators': 100}
# 40         {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 5, 'n_estimators': 100}
# 27       {'max_depth': 6, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 50}
# 42         {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 10, 'n_estimators': 50}
# 39          {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 5, 'n_estimators': 50}
# 38         {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 200}
# 37         {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 100}
# 36          {'max_depth': 6, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 50}
# 53        {'max_depth': 6, 'max_features': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# 50         {'max_depth': 6, 'max_features': 2, 'min_samples_leaf': 5, 'n_estimators': 200}
# 52        {'max_depth': 6, 'max_features': 2, 'min_samples_leaf': 10, 'n_estimators': 100}
# 49         {'max_depth': 6, 'max_features': 2, 'min_samples_leaf': 5, 'n_estimators': 100}
# 51         {'max_depth': 6, 'max_features': 2, 'min_samples_leaf': 10, 'n_estimators': 50}
# 47         {'max_depth': 6, 'max_features': 2, 'min_samples_leaf': 1, 'n_estimators': 200}
# 48          {'max_depth': 6, 'max_features': 2, 'min_samples_leaf': 5, 'n_estimators': 50}
# 46         {'max_depth': 6, 'max_features': 2, 'min_samples_leaf': 1, 'n_estimators': 100}
# 45          {'max_depth': 6, 'max_features': 2, 'min_samples_leaf': 1, 'n_estimators': 50}
# 8      {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'n_estimators': 200}
# 7      {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'n_estimators': 100}
# 17        {'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 10, 'n_estimators': 200}
# 6       {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'n_estimators': 50}
# 5       {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 200}
# 4       {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 100}
# 16        {'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 10, 'n_estimators': 100}
# 14         {'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 5, 'n_estimators': 200}
# 3        {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'n_estimators': 50}
# 13         {'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 5, 'n_estimators': 100}
# 15         {'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 10, 'n_estimators': 50}
# 2       {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 200}
# 1       {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 100}
# 11         {'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 200}
# 0        {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 50}
# 12          {'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 5, 'n_estimators': 50}
# 10         {'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 100}
# 9           {'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 1, 'n_estimators': 50}
# 26        {'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 10, 'n_estimators': 200}
# 23         {'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 5, 'n_estimators': 200}
# 20         {'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 1, 'n_estimators': 200}
# 25        {'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 10, 'n_estimators': 100}
# 24         {'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 10, 'n_estimators': 50}
# 22         {'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 5, 'n_estimators': 100}
# 21          {'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 5, 'n_estimators': 50}
# 19         {'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 1, 'n_estimators': 100}
# 18          {'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 1, 'n_estimators': 50}
#
#     mean_test_score  std_test_score  mean_train_score
# 65         0.748954        0.097339          0.964524
# 56         0.748619        0.105361          0.964307
# 55         0.746483        0.105639          0.963281
# 64         0.745839        0.096776          0.963471
# 63         0.742806        0.095366          0.962624
# 59         0.741669        0.105470          0.859758
# 73         0.741378        0.095392          0.962657
# 74         0.740881        0.094959          0.963561
# 54         0.740724        0.109204          0.962312
# 58         0.740205        0.105767          0.859221
# 57         0.738678        0.106262          0.858337
# 68         0.738346        0.100682          0.853271
# 72         0.738267        0.094169          0.961427
# 67         0.736813        0.101096          0.852644
# 66         0.734751        0.100446          0.852573
# 62         0.723692        0.103387          0.810218
# 61         0.722848        0.103613          0.809593
# 77         0.721289        0.094375          0.835860
# 60         0.720730        0.102960          0.808874
# 76         0.720446        0.094880          0.835202
# 70         0.719392        0.097459          0.801651
# 71         0.719152        0.097820          0.802112
# 69         0.717118        0.097992          0.800897
# 75         0.716518        0.095902          0.834715
# 80         0.698659        0.091733          0.778204
# 79         0.697354        0.092087          0.777266
# 78         0.695131        0.092186          0.775996
# 35         0.627287        0.087923          0.683383
# 34         0.626632        0.087204          0.683013
# 33         0.625970        0.087995          0.682712
# 32         0.625250        0.086912          0.694392
# 31         0.624180        0.086428          0.694290
# 30         0.622473        0.086987          0.693451
# 44         0.607763        0.080447          0.659721
# 29         0.607600        0.085148          0.729806
# 41         0.607583        0.078960          0.672014
# 28         0.606430        0.084617          0.729231
# 43         0.605370        0.080916          0.656629
# 40         0.603922        0.078861          0.668780
# 27         0.601729        0.086703          0.728695
# 42         0.601335        0.081587          0.653903
# 39         0.601334        0.078896          0.665169
# 38         0.594523        0.074953          0.704034
# 37         0.591751        0.075941          0.702312
# 36         0.582299        0.075110          0.696641
# 53         0.552718        0.067976          0.601500
# 50         0.551196        0.066611          0.612391
# 52         0.547010        0.065208          0.595942
# 49         0.544275        0.065111          0.606021
# 51         0.543507        0.064420          0.593665
# 47         0.541616        0.065438          0.639099
# 48         0.540092        0.063915          0.602677
# 46         0.534526        0.065674          0.631730
# 45         0.533717        0.067038          0.630009
# 8          0.329631        0.044396          0.349472
# 7          0.329513        0.044435          0.349405
# 17         0.329111        0.040380          0.347707
# 6          0.328855        0.044882          0.348144
# 5          0.327138        0.042860          0.349360
# 4          0.326848        0.042778          0.349311
# 16         0.326559        0.040325          0.344453
# 14         0.326557        0.039738          0.347047
# 3          0.325884        0.042953          0.348467
# 13         0.323135        0.039197          0.343467
# 15         0.322779        0.040688          0.340341
# 2          0.322488        0.041476          0.350764
# 1          0.321397        0.040905          0.350743
# 11         0.321269        0.037714          0.348039
# 0          0.320117        0.041097          0.350335
# 12         0.318044        0.038646          0.338519
# 10         0.317731        0.037637          0.344719
# 9          0.312541        0.036819          0.339230
# 26         0.279147        0.032319          0.296385
# 23         0.276595        0.032189          0.295519
# 20         0.273016        0.031077          0.297336
# 25         0.268234        0.032204          0.285335
# 24         0.267517        0.031444          0.285402
# 22         0.265167        0.031348          0.284655
# 21         0.264615        0.030644          0.285013
# 19         0.261545        0.030166          0.286738
# 18         0.260611        0.029575          0.287509

# %% [markdown]
# ### Discussion Question:
#
# #### Do we need to explore some parameters more in detail (i.e., do we expect a significant improvement by enlarging the space of parameters?)
#
# Probably not, because the scores are flat-ish over the first 10-20 models, suggesting that further optimization is unlikely to help significantly.

# %%
bm = model.best_estimator_

# %% [markdown]
# We can generate one set of predictions to visualize what happens.

# %%
ypred = cross_val_predict(bm, sel_features,sel_target, cv = KFold(n_splits=5, shuffle=True, random_state=10))

# %%
plt.figure(figsize=(7,7))
plt.scatter(sel_target,ypred, s =10)
plt.xlabel('z_spec')
plt.ylabel('z_photo')
plt.ylim(0,2)
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %% [markdown]
# Calculate the outlier fraction:

# %%
len(np.where(np.abs(sel_target-ypred)>0.15*(1+sel_target))[0])/len(sel_target)
# Out:
# 0.05660377358490566

# %% [markdown]
# Calculate Normalized Median Absolute Deviation (NMAD).

# %%
1.48*np.median(np.abs(sel_target-ypred)/(1 + sel_target))
# Out:
# np.float64(0.03674065305957637)

# %% [markdown]
# ### Conclusion Questions:
#
# How does our model compare with the paper's results?
#
# Reminder, the paper results were:
#
# outlier fraction = 4.54%
#
# NMAD = 0.0174

# %% [markdown]
# >Our outlier fraction was 5.66% which is slightly higher than the paper's results
#
# >Our NMAD is 0.0367 which is about twice as big as the paper found

# %% [markdown]
# What is one other thing we can try to get closer to the paper performance?

# %% [markdown]
# >We can try feature engineering by including ratios of the colors instead of just the absolute value.

# %% [markdown]
# ### <font color='blue'> Until now, we have never discussed a very important point: how to estimate the uncertainty associated to our results. </font>
#
# If you run out of time, submit your studio to Gradescope without completing this section (but you'll want to revisit it for work on your project)! If you do have time, work through it now.

# %% [markdown]
# One source of scatter on the global performance metrics comes from the system's architecture: we should generate a bunch of predictions with several random seeds. This is equivalent to the scatter found in the monitored metric (e.g., MSE or r2 score) in cross validation.

# %%
model = RandomForestRegressor(max_features=4, n_estimators=200) #I need to re-seed the random state

# %%
#Note: this also takes time!

seeds = np.random.choice(100,8, replace = False) #pick 8

olf = np.zeros(8)
NMAD = np.zeros(8)

for i in range(8): #A bit rough, but it gives a sense of what happens by varying the random seeds!
    print('Iteration', i)
    ypred = cross_val_predict(RandomForestRegressor(max_features=4, n_estimators=200,random_state=seeds[i]), sel_features, sel_target, cv = KFold(n_splits=5, shuffle=True, random_state=seeds[i]))
    olf[i] = len(np.where(np.abs(sel_target-ypred)>0.15*(1+sel_target))[0])/len(sel_target)
    NMAD[i] = 1.48*np.median(np.abs(sel_target-ypred)/(1 + sel_target))

print('OLF avg/std:, {0:.5f}, {1:0.5f}'.format(olf.mean(), olf.std()))
print('NMAD avg/std:, {0:.5f}, {1:0.5f}'.format(NMAD.mean(), NMAD.std()))
# Out:
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# OLF avg/std:, 0.05708, 0.00081
# NMAD avg/std:, 0.03687, 0.00041

# %% [markdown]
# #### However, we should also think about how to quantify the observational error on our *individual* inputs.
#
# The literature on this subjects is scarce, but my proposal is to run a forward-pass of the best model a bunch of times, with different inputs that are drawn from modeling each input according to their noise profile (e.g. a Gaussian where mean = observed value and sigma = experimental error).
#
# Assuming that the noise profile doesn't change from the "true" value to the "observed" value, this should include the experimental error and the "limited information" error, which comes from limited training set size, lack of informative features, model architecture etc. This has been described as epistemic vs aleatoric uncertainty (see [this recent review](https://link.springer.com/article/10.1007/s10994-021-05946-3)).

# %% [markdown]
# ### Acknowledgement statement:

# %% [markdown]
# >The authors acknowledge Dr. Gruszko for input on feature engineering.

# %% [markdown]
# ### That's it for Random Forests, for now! Upload your completed notebook to Gradescope to submit it.
