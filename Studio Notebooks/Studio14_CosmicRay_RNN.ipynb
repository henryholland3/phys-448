# %% [markdown]
# # Studio 14: Finding Cosmic Ray Signals with RNNs
#
# Adapted from https://deeplearningforphysicsresearchbook.github.io/deep-learning-physics/ by Javier Duarte (2023)
#
# Further modifications by Julieta Gruszko (2025)
#
# Large arrays of radio antennas can be used to measure cosmic rays by recording the electromagnetic radiation generated in the atmosphere.
# These radio signals are strongly contaminated by galactic noise as well as signals from human origin. Since these signals appear to be similar to the background, the discovery of cosmic-ray events can be challenging.
#
# The data file for this studio is a bit too large to host on Github. It's available on Canvas instead, go ahead and download it from there.
#
# ## Identification of signals
# In this exercise, we design an RNN to classify if the recorded radio signals contain a cosmic-ray event or only noise.
#
# The signal-to-noise ratio (SNR) of a measured trace $S(t)$ is defined as follows:
#
# $SNR=\frac{|S(t)_{max}|}{RMS[S(t)]}$
#
# where $|S(t)_{max}|$ denotes the maximum amplitude of the (true) signal.
#
# Typical cosmic-ray observatories enable a precise reconstruction at an SNR of roughly 3.
#
# We choose a challenging setup in this task and try to identify cosmic-ray events in signal traces with an SNR of 2.

# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler

import matplotlib
import matplotlib.pyplot as plt

import torch as torch
import torch.nn as nn

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

# %% [markdown]
# Training RNNs can be computationally demanding, thus, we recommend to use a GPU for this task if possible.
# ### Depending on your computer, you should run just one of the two options below to switch to GPU, if available.

# %% [markdown]
# ### For Macs:
# If you have an Apple Silicon chip in your laptop (e.g. M1 or above), you can use the integrated GPU by running the code below.

# %%
# !xcode-select --install
# Out:
# xcode-select: note: Command line tools are already installed. Use "Software Update" in System Settings or the softwareupdate command line interface to install updates

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple GPU with Metal backend.")
else:
    device = torch.device("cpu")
    print("Using CPU.")
# Out:
# Using Apple GPU with Metal backend.

# %% [markdown]
# ### For Others:
# If you have a non-Mac computer, you can check for an available GPU with by running this code:

# %%
if torch.cuda.is_available():
    print("GPU is available for PyTorch.")
    print(f"Number of GPUs available: {torch.cuda.device_count()}")
    print(f"Current GPU device name: {torch.cuda.get_device_name(0)}") # Get name of the first GPU
else:
    print("GPU is NOT available for PyTorch. Using CPU.")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import keras

from keras import Input

from keras.models import Sequential #the model is built adding layers one after the other

from keras.layers import Dense #fully connected layers: every output talks to every input

from keras.layers import Activation

from keras.layers import SimpleRNN, LSTM, Bidirectional, Flatten, Dropout

# %% [markdown]
# ### Load and prepare dataset
# In this task, we use a simulation of cosmic-ray-induced air showers that are measured by radion antennas.
# For more information, see https://arxiv.org/abs/1901.04079.
# The task is to design an RNN which is able to identify if the measured signal traces (shortened to 500 time steps) contains a signal or not.

# %%
f = np.load("../Data/cosmic-radio-showers_with_signals.npz")

# %% [markdown]
# The file contains measured traces, labels, and for cosmic-ray events, the true signal. For non cosmic-ray events, the signal object is set to 0. The traces and signals are each 500 samples long.

# %%
f.files
# Out:
# ['traces', 'labels', 'signals']

# %% [markdown]
# ## Plot example signal traces
# Left: signal trace containing a cosmic-ray event. The underlying cosmic-ray signal is shown in red, the backgrounds + signal is shown in blue.
# Right: background noise, with 0 underlying signal trace.

# %%
from matplotlib import pyplot as plt
fs = 180e6  # Sampling frequency of antenna setup 180 MHz
t = np.arange(500) / fs * 1e6
idx_sig = 54 #pick the n'th signal trace in the file
idx_noise = 17 #pick the n'th noise trace in the file

plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(t, np.real(f["traces"][np.where(f["labels"] == 1)][idx_sig]), linewidth = 1, color="b", label="Measured trace")
plt.plot(t, np.real(f["signals"][np.where(f["labels"] == 1)][idx_sig]), linewidth = 1, color="r", label="CR signal")
plt.ylabel('Amplitude / mV')
plt.xlabel('Time / $\mu$ s')
plt.legend()
plt.title("Cosmic-ray event")
plt.subplot(1, 2, 2)

plt.plot(t, np.real(f["traces"][np.where(f["labels"] == 0)][idx_noise]), linewidth = 1, color="b", label="Measured trace")
plt.plot(t, np.real(f["signals"][np.where(f["labels"] == 0)][idx_noise]), linewidth = 1, color="r", label="CR signal")

plt.ylabel('Amplitude / mV')
plt.xlabel('Time / $\mu$ s')
plt.legend()
plt.title("Noise event")

plt.grid(True)
plt.tight_layout()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/jr/svbnrsxx2gddc8x3xhz_57b40000gn/T/ipykernel_23040/2179829671.py:12: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Time / $\mu$ s')
# /var/folders/jr/svbnrsxx2gddc8x3xhz_57b40000gn/T/ipykernel_23040/2179829671.py:21: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Time / $\mu$ s')

# %%
np.shape(f['traces'])
# Out:
# (50000, 500)

# %%
print(np.shape(f['labels'][f['labels']==1])) # cosmic ray events
print(np.shape(f['labels'][f['labels']==0])) # noise events
# Out:
# (25078,)
# (24922,)

# %% [markdown]
# ### Questions:
# - How many instances are in our learning set?
# - Is the data set balanced or unbalanced?
# - In this notebook, we'll try to identify whether a signal is present in each trace. When type of RNN structure do we need to use? E.g. sequence-to-sequence, vector-to-sequence, or sequence-to-vector?
# - What type of task are we performing (e.g. classification, regression, generation)? What type of activation function should our final layer use? What type of loss should we optimize?

# %% [markdown]
# >There are about 50,000 instances in our learning set.
#
# >The data set is balanced. There are 25,078 instances of cosmic ray events and 24,922 instances of noise events.
#
# >We need to use a sequence-to-vector RNN structure.
#
# >We are performing a classification task (identifying whether a signal is present in each trace). We should use a sigmoid activation function for the final layer and binary cross entropy for the loss function.

# %% [markdown]
# As we did last week, we will use sk-learn's $\texttt{train\_test\_split}$ to split the data in to random selections with appropriate fractions. This time, instead of making a validation set ourselves, we'll use Keras's built-in validation split option. We'll just split off test data for now.

# %%
# split the samples into training and test data sets:
train_frac = 0.8
test_frac = 0.2

x_train, x_test, y_train, y_test = train_test_split(
    f["traces"], f['labels'], test_size=test_frac, random_state=42
)

# %% [markdown]
# ### Scaling
# Let's scale the data so that the train data traces have standard deviation of 1. We won't bother shifting the mean, since the data traces are already centered around 0. We could use sk-learn's Standard Scaler object to do this, but it's also easy enough to do it by hand.

# %%
sigma = x_train.std()
x_train /= sigma
x_test /= sigma

# %%
x_train.std()
# Out:
# np.float32(1.0000002)

# %% [markdown]
# ### Define RNN model
# In the following, design a cosmic-ray model to identify cosmic-ray events using an RNN-based classifier.
#
# We'll start with a Simple RNN, then try a bi-directional RNN, then finally a one-direction LSTM.
#
# By default, the output of an RNN layer contains a single vector per sample. This vector is the RNN cell output corresponding to the last timestep, containing information about the entire input sequence. The shape of this output is $\texttt{(batch\_size, units)}$ where $\texttt{units}$ corresponds to the units argument passed to the layer's constructor.
#
# A RNN layer can also return the entire sequence of outputs for each sample (one vector per timestep per sample), if you set $\texttt{return\_sequences=True}$. The shape of this output is $\texttt{(batch\_size, timesteps, units)}$.
#
# $\texttt{return\_sequences=True}$ is used when you want to return a sequence (e.g. one-to-many and many-to-many RNNs). When you're stacking RNN layers, as we do below, each RNN layer is expecting a sequence as an input, so you'll want to keep it set to $\texttt{True}$. In the final RNN layer for a many-to-one RNN, we can choose: either we can either use an RNN layer as the last step, setting it to $\texttt{False}$ to return a single value, or we can output the sequence from our last RNN layer, sending it to a fully connected layer with a single output for the last step.
#
#
# ## RNN 1: Simple RNN
#
# This model is probably a bit too shallow to perform really well, but we'll keep it simple to reduce the training time to something that can be done in class. The commented-out layer can be reintroduced if you want to try something deeper later on.

# %%
model_rnn = Sequential()
model_rnn.add(keras.Input(shape=(500, 1)))
model_rnn.add(SimpleRNN(32, return_sequences=True, recurrent_initializer="glorot_uniform"))
#model_rnn.add(SimpleRNN(64, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_rnn.add(SimpleRNN(10, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_rnn.add(Flatten())
model_rnn.add(Dropout(0.3))
model_rnn.add(Dense(1, activation="sigmoid"))

model_rnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 500, 32)        │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 500, 10)        │           430 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 5000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         5,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,519 (25.46 KB)
#  Trainable params: 6,519 (25.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Questions:
# - How many hidden layers does this model have?
# - How many free parameters?

# %% [markdown]
# >This model has 2 hidden layers (simple_rnn, simple_rnn_1)
#
# >There are 6,519 free parameters.

# %% [markdown]
# ### Compile the model
#
# We'll use AdamW, our old standby optimizer. This time we'll set the $\texttt{weight\_decay}$ option to a smaller value than the default; this parameter controls how strong the regularization is.

# %%
model_rnn.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.AdamW(1e-3, weight_decay=0.00008),
    metrics=['accuracy'])

# %% [markdown]
# ### Fitting the model on GPU
#
# To actually run the training on GPU, we'll need to explicitly move the data over to the GPU. Once the data is on GPU, Keras automatically handles sending the model to GPU for training. To move the data over, we first need to switch it from a numpy array to a torch tensor.
#
# If you ran the right cells above, $\texttt{device}$ should be set correctly for your computer (CPU if you don't have a GPU, or the appropriate GPU options for Macs or non-Macs).

# %%
x_train = torch.from_numpy(x_train)
x_train = x_train.to(device)

y_train = torch.from_numpy(y_train)
y_train = y_train.to(device)

x_test = torch.from_numpy(x_test)
x_test = x_test.to(device)

y_test = torch.from_numpy(y_test)
y_test = y_test.to(device)

# %% [markdown]
# For the fit, we're going to use a couple of new options that should help the optimization process avoid some of the pitfalls we saw last week:
# - Reduce the learning rate when the loss stops improving, so your optimizer takes smaller steps when it's getting close to the minimum.
# - Apply early stopping, so training stops if the loss doesn't improve after some number of generations.
#
# Even using a GPU, training RNN's is very slow: they need to process samples one at a time. On my laptop (using an M2 GPU) this model took about 26 seconds per epoch to train; about 13 minutes in total.
#
# 30 epochs is probably a bit short, but it should be close enough while keeping to our time constraints.

# %%
results_rnn = model_rnn.fit(x_train[...,np.newaxis], y_train,
                    batch_size=1024,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1,
                    callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
                                 keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
                    )
# Out:
# Epoch 1/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 28s 750ms/step - accuracy: 0.5040 - loss: 0.7179 - val_accuracy: 0.5612 - val_loss: 0.6824 - learning_rate: 0.0010
# Epoch 2/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.6007 - loss: 0.6621 - val_accuracy: 0.6975 - val_loss: 0.6030 - learning_rate: 0.0010
# Epoch 3/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.6601 - loss: 0.6186 - val_accuracy: 0.7262 - val_loss: 0.5607 - learning_rate: 0.0010
# Epoch 4/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 735ms/step - accuracy: 0.6891 - loss: 0.5944 - val_accuracy: 0.7337 - val_loss: 0.5507 - learning_rate: 0.0010
# Epoch 5/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 731ms/step - accuracy: 0.6978 - loss: 0.5829 - val_accuracy: 0.7100 - val_loss: 0.5649 - learning_rate: 0.0010
# Epoch 6/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 757ms/step - accuracy: 0.6919 - loss: 0.5903 - val_accuracy: 0.6323 - val_loss: 0.6508 - learning_rate: 0.0010
# Epoch 7/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 737ms/step - accuracy: 0.6985 - loss: 0.5811 - val_accuracy: 0.7440 - val_loss: 0.5393 - learning_rate: 0.0010
# Epoch 8/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 719ms/step - accuracy: 0.7045 - loss: 0.5717 - val_accuracy: 0.7427 - val_loss: 0.5385 - learning_rate: 0.0010
# Epoch 9/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 719ms/step - accuracy: 0.7056 - loss: 0.5734 - val_accuracy: 0.7450 - val_loss: 0.5330 - learning_rate: 0.0010
# Epoch 10/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 726ms/step - accuracy: 0.7126 - loss: 0.5632 - val_accuracy: 0.7393 - val_loss: 0.5427 - learning_rate: 0.0010
# Epoch 11/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 725ms/step - accuracy: 0.7076 - loss: 0.5694 - val_accuracy: 0.7147 - val_loss: 0.5685 - learning_rate: 0.0010
# Epoch 12/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 727ms/step - accuracy: 0.7111 - loss: 0.5666 - val_accuracy: 0.7458 - val_loss: 0.5289 - learning_rate: 0.0010
# Epoch 13/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 738ms/step - accuracy: 0.7207 - loss: 0.5519 - val_accuracy: 0.7303 - val_loss: 0.5375 - learning_rate: 0.0010
# Epoch 14/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 726ms/step - accuracy: 0.7124 - loss: 0.5645 - val_accuracy: 0.7138 - val_loss: 0.5715 - learning_rate: 0.0010
# Epoch 15/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 718ms/step - accuracy: 0.7107 - loss: 0.5656 - val_accuracy: 0.7415 - val_loss: 0.5287 - learning_rate: 0.0010
# Epoch 16/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 722ms/step - accuracy: 0.7207 - loss: 0.5507 - val_accuracy: 0.7122 - val_loss: 0.5634 - learning_rate: 0.0010
# Epoch 17/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 722ms/step - accuracy: 0.7184 - loss: 0.5568 - val_accuracy: 0.7433 - val_loss: 0.5270 - learning_rate: 0.0010
# Epoch 18/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.7134 - loss: 0.5605 - val_accuracy: 0.7380 - val_loss: 0.5341 - learning_rate: 0.0010
# Epoch 19/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 730ms/step - accuracy: 0.7149 - loss: 0.5556 - val_accuracy: 0.7000 - val_loss: 0.5865 - learning_rate: 0.0010
# Epoch 20/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 745ms/step - accuracy: 0.7121 - loss: 0.5613 - val_accuracy: 0.7442 - val_loss: 0.5289 - learning_rate: 0.0010
# Epoch 21/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 732ms/step - accuracy: 0.7214 - loss: 0.5508 - val_accuracy: 0.7458 - val_loss: 0.5233 - learning_rate: 0.0010
# Epoch 22/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 735ms/step - accuracy: 0.7235 - loss: 0.5466 - val_accuracy: 0.7377 - val_loss: 0.5290 - learning_rate: 0.0010
# Epoch 23/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 741ms/step - accuracy: 0.7192 - loss: 0.5535 - val_accuracy: 0.7408 - val_loss: 0.5247 - learning_rate: 0.0010
# Epoch 24/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 716ms/step - accuracy: 0.7145 - loss: 0.5615 - val_accuracy: 0.7318 - val_loss: 0.5385 - learning_rate: 0.0010
# Epoch 25/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 718ms/step - accuracy: 0.7191 - loss: 0.5524 - val_accuracy: 0.7107 - val_loss: 0.5593 - learning_rate: 0.0010
# Epoch 26/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - accuracy: 0.7144 - loss: 0.5542
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 715ms/step - accuracy: 0.7196 - loss: 0.5508 - val_accuracy: 0.7283 - val_loss: 0.5398 - learning_rate: 0.0010
# Epoch 27/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 731ms/step - accuracy: 0.7274 - loss: 0.5409 - val_accuracy: 0.7425 - val_loss: 0.5240 - learning_rate: 5.0000e-04
# Epoch 28/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 723ms/step - accuracy: 0.7278 - loss: 0.5370 - val_accuracy: 0.7405 - val_loss: 0.5272 - learning_rate: 5.0000e-04
# Epoch 29/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.7296 - loss: 0.5385 - val_accuracy: 0.7442 - val_loss: 0.5203 - learning_rate: 5.0000e-04
# Epoch 30/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 725ms/step - accuracy: 0.7299 - loss: 0.5357 - val_accuracy: 0.7455 - val_loss: 0.5197 - learning_rate: 5.0000e-04

# %% [markdown]
# ### Questions:
# - Describe the conditions that will lead the learning rate to be reduced, given our settings above.
# - Did the automated loss rate reduction we applied kick in during training? If yes, how many times was a reduction in loss rate applied?
# - Describe the conditions that will lead to early stopping, given our settings above.
# - Did early stopping kick in during training?

# %% [markdown]
# >The learning rate will be reduced when val_loss doesn't improve by at least 0.0005 over 5 epochs
#
# >Yes. The automated loss rate reduction kicked in during training. The reduction in loss rate was applied once.
#
# >Early stopping will happen when val_loss doesn't improve by 0.0001 over 10 epochs.
#
# >No. Early stopping did not kick in during training.

# %% [markdown]
# # Studio 14: Finding Cosmic Ray Signals with RNNs
#
# Adapted from https://deeplearningforphysicsresearchbook.github.io/deep-learning-physics/ by Javier Duarte (2023)
#
# Further modifications by Julieta Gruszko (2025)
#
# Large arrays of radio antennas can be used to measure cosmic rays by recording the electromagnetic radiation generated in the atmosphere.
# These radio signals are strongly contaminated by galactic noise as well as signals from human origin. Since these signals appear to be similar to the background, the discovery of cosmic-ray events can be challenging.
#
# The data file for this studio is a bit too large to host on Github. It's available on Canvas instead, go ahead and download it from there.
#
# ## Identification of signals
# In this exercise, we design an RNN to classify if the recorded radio signals contain a cosmic-ray event or only noise.
#
# The signal-to-noise ratio (SNR) of a measured trace $S(t)$ is defined as follows:
#
# $SNR=\frac{|S(t)_{max}|}{RMS[S(t)]}$
#
# where $|S(t)_{max}|$ denotes the maximum amplitude of the (true) signal.
#
# Typical cosmic-ray observatories enable a precise reconstruction at an SNR of roughly 3.
#
# We choose a challenging setup in this task and try to identify cosmic-ray events in signal traces with an SNR of 2.

# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler

import matplotlib
import matplotlib.pyplot as plt

import torch as torch
import torch.nn as nn

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

# %% [markdown]
# Training RNNs can be computationally demanding, thus, we recommend to use a GPU for this task if possible.
# ### Depending on your computer, you should run just one of the two options below to switch to GPU, if available.

# %% [markdown]
# ### For Macs:
# If you have an Apple Silicon chip in your laptop (e.g. M1 or above), you can use the integrated GPU by running the code below.

# %%
# !xcode-select --install
# Out:
# xcode-select: note: Command line tools are already installed. Use "Software Update" in System Settings or the softwareupdate command line interface to install updates

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple GPU with Metal backend.")
else:
    device = torch.device("cpu")
    print("Using CPU.")
# Out:
# Using Apple GPU with Metal backend.

# %% [markdown]
# ### For Others:
# If you have a non-Mac computer, you can check for an available GPU with by running this code:

# %%
if torch.cuda.is_available():
    print("GPU is available for PyTorch.")
    print(f"Number of GPUs available: {torch.cuda.device_count()}")
    print(f"Current GPU device name: {torch.cuda.get_device_name(0)}") # Get name of the first GPU
else:
    print("GPU is NOT available for PyTorch. Using CPU.")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# GPU is NOT available for PyTorch. Using CPU.

# %%
import keras

from keras import Input

from keras.models import Sequential #the model is built adding layers one after the other

from keras.layers import Dense #fully connected layers: every output talks to every input

from keras.layers import Activation

from keras.layers import SimpleRNN, LSTM, Bidirectional, Flatten, Dropout

# %% [markdown]
# ### Load and prepare dataset
# In this task, we use a simulation of cosmic-ray-induced air showers that are measured by radion antennas.
# For more information, see https://arxiv.org/abs/1901.04079.
# The task is to design an RNN which is able to identify if the measured signal traces (shortened to 500 time steps) contains a signal or not.

# %%
f = np.load("../Data/cosmic-radio-showers_with_signals.npz")

# %% [markdown]
# The file contains measured traces, labels, and for cosmic-ray events, the true signal. For non cosmic-ray events, the signal object is set to 0. The traces and signals are each 500 samples long.

# %%
f.files
# Out:
# ['traces', 'labels', 'signals']

# %% [markdown]
# ## Plot example signal traces
# Left: signal trace containing a cosmic-ray event. The underlying cosmic-ray signal is shown in red, the backgrounds + signal is shown in blue.
# Right: background noise, with 0 underlying signal trace.

# %%
from matplotlib import pyplot as plt
fs = 180e6  # Sampling frequency of antenna setup 180 MHz
t = np.arange(500) / fs * 1e6
idx_sig = 54 #pick the n'th signal trace in the file
idx_noise = 17 #pick the n'th noise trace in the file

plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(t, np.real(f["traces"][np.where(f["labels"] == 1)][idx_sig]), linewidth = 1, color="b", label="Measured trace")
plt.plot(t, np.real(f["signals"][np.where(f["labels"] == 1)][idx_sig]), linewidth = 1, color="r", label="CR signal")
plt.ylabel('Amplitude / mV')
plt.xlabel('Time / $\mu$ s')
plt.legend()
plt.title("Cosmic-ray event")
plt.subplot(1, 2, 2)

plt.plot(t, np.real(f["traces"][np.where(f["labels"] == 0)][idx_noise]), linewidth = 1, color="b", label="Measured trace")
plt.plot(t, np.real(f["signals"][np.where(f["labels"] == 0)][idx_noise]), linewidth = 1, color="r", label="CR signal")

plt.ylabel('Amplitude / mV')
plt.xlabel('Time / $\mu$ s')
plt.legend()
plt.title("Noise event")

plt.grid(True)
plt.tight_layout()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/jr/svbnrsxx2gddc8x3xhz_57b40000gn/T/ipykernel_23040/2179829671.py:12: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Time / $\mu$ s')
# /var/folders/jr/svbnrsxx2gddc8x3xhz_57b40000gn/T/ipykernel_23040/2179829671.py:21: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Time / $\mu$ s')

# %%
np.shape(f['traces'])
# Out:
# (50000, 500)

# %%
print(np.shape(f['labels'][f['labels']==1])) # cosmic ray events
print(np.shape(f['labels'][f['labels']==0])) # noise events
# Out:
# (25078,)
# (24922,)

# %% [markdown]
# ### Questions:
# - How many instances are in our learning set?
# - Is the data set balanced or unbalanced?
# - In this notebook, we'll try to identify whether a signal is present in each trace. When type of RNN structure do we need to use? E.g. sequence-to-sequence, vector-to-sequence, or sequence-to-vector?
# - What type of task are we performing (e.g. classification, regression, generation)? What type of activation function should our final layer use? What type of loss should we optimize?

# %% [markdown]
# >There are about 50,000 instances in our learning set.
#
# >The data set is balanced. There are 25,078 instances of cosmic ray events and 24,922 instances of noise events.
#
# >We need to use a sequence-to-vector RNN structure.
#
# >We are performing a classification task (identifying whether a signal is present in each trace). We should use a sigmoid activation function for the final layer and binary cross entropy for the loss function.

# %% [markdown]
# As we did last week, we will use sk-learn's $\texttt{train\_test\_split}$ to split the data in to random selections with appropriate fractions. This time, instead of making a validation set ourselves, we'll use Keras's built-in validation split option. We'll just split off test data for now.

# %%
# split the samples into training and test data sets:
train_frac = 0.8
test_frac = 0.2

x_train, x_test, y_train, y_test = train_test_split(
    f["traces"], f['labels'], test_size=test_frac, random_state=42
)

# %% [markdown]
# ### Scaling
# Let's scale the data so that the train data traces have standard deviation of 1. We won't bother shifting the mean, since the data traces are already centered around 0. We could use sk-learn's Standard Scaler object to do this, but it's also easy enough to do it by hand.

# %%
sigma = x_train.std()
x_train /= sigma
x_test /= sigma

# %%
x_train.std()
# Out:
# np.float32(1.0000002)

# %% [markdown]
# ### Define RNN model
# In the following, design a cosmic-ray model to identify cosmic-ray events using an RNN-based classifier.
#
# We'll start with a Simple RNN, then try a bi-directional RNN, then finally a one-direction LSTM.
#
# By default, the output of an RNN layer contains a single vector per sample. This vector is the RNN cell output corresponding to the last timestep, containing information about the entire input sequence. The shape of this output is $\texttt{(batch\_size, units)}$ where $\texttt{units}$ corresponds to the units argument passed to the layer's constructor.
#
# A RNN layer can also return the entire sequence of outputs for each sample (one vector per timestep per sample), if you set $\texttt{return\_sequences=True}$. The shape of this output is $\texttt{(batch\_size, timesteps, units)}$.
#
# $\texttt{return\_sequences=True}$ is used when you want to return a sequence (e.g. one-to-many and many-to-many RNNs). When you're stacking RNN layers, as we do below, each RNN layer is expecting a sequence as an input, so you'll want to keep it set to $\texttt{True}$. In the final RNN layer for a many-to-one RNN, we can choose: either we can either use an RNN layer as the last step, setting it to $\texttt{False}$ to return a single value, or we can output the sequence from our last RNN layer, sending it to a fully connected layer with a single output for the last step.
#
#
# ## RNN 1: Simple RNN
#
# This model is probably a bit too shallow to perform really well, but we'll keep it simple to reduce the training time to something that can be done in class. The commented-out layer can be reintroduced if you want to try something deeper later on.

# %%
model_rnn = Sequential()
model_rnn.add(keras.Input(shape=(500, 1)))
model_rnn.add(SimpleRNN(32, return_sequences=True, recurrent_initializer="glorot_uniform"))
#model_rnn.add(SimpleRNN(64, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_rnn.add(SimpleRNN(10, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_rnn.add(Flatten())
model_rnn.add(Dropout(0.3))
model_rnn.add(Dense(1, activation="sigmoid"))

model_rnn.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)        │ (None, 500, 32)        │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_5 (SimpleRNN)        │ (None, 500, 10)        │           430 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 5000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 5000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │         5,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,519 (25.46 KB)
#  Trainable params: 6,519 (25.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Questions:
# - How many hidden layers does this model have?
# - How many free parameters?

# %% [markdown]
# >This model has 2 hidden layers (simple_rnn, simple_rnn_1)
#
# >There are 6,519 free parameters.

# %% [markdown]
# ### Compile the model
#
# We'll use AdamW, our old standby optimizer. This time we'll set the $\texttt{weight\_decay}$ option to a smaller value than the default; this parameter controls how strong the regularization is.

# %%
model_rnn.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.AdamW(1e-3, weight_decay=0.00008),
    metrics=['accuracy'])

# %% [markdown]
# ### Fitting the model on GPU
#
# To actually run the training on GPU, we'll need to explicitly move the data over to the GPU. Once the data is on GPU, Keras automatically handles sending the model to GPU for training. To move the data over, we first need to switch it from a numpy array to a torch tensor.
#
# If you ran the right cells above, $\texttt{device}$ should be set correctly for your computer (CPU if you don't have a GPU, or the appropriate GPU options for Macs or non-Macs).

# %%
x_train = torch.from_numpy(x_train)
x_train = x_train.to(device)

y_train = torch.from_numpy(y_train)
y_train = y_train.to(device)

x_test = torch.from_numpy(x_test)
x_test = x_test.to(device)

y_test = torch.from_numpy(y_test)
y_test = y_test.to(device)

# %% [markdown]
# For the fit, we're going to use a couple of new options that should help the optimization process avoid some of the pitfalls we saw last week:
# - Reduce the learning rate when the loss stops improving, so your optimizer takes smaller steps when it's getting close to the minimum.
# - Apply early stopping, so training stops if the loss doesn't improve after some number of generations.
#
# Even using a GPU, training RNN's is very slow: they need to process samples one at a time. On my laptop (using an M2 GPU) this model took about 26 seconds per epoch to train; about 13 minutes in total.
#
# 30 epochs is probably a bit short, but it should be close enough while keeping to our time constraints.

# %%
results_rnn = model_rnn.fit(x_train[...,np.newaxis], y_train,
                    batch_size=1024,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1,
                    callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
                                 keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
                    )
# Out:
# Epoch 1/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 726ms/step - accuracy: 0.5044 - loss: 0.7265 - val_accuracy: 0.5242 - val_loss: 0.6940 - learning_rate: 0.0010
# Epoch 2/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 743ms/step - accuracy: 0.5260 - loss: 0.6980 - val_accuracy: 0.5552 - val_loss: 0.6839 - learning_rate: 0.0010
# Epoch 3/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 28s 766ms/step - accuracy: 0.5444 - loss: 0.6907 - val_accuracy: 0.5555 - val_loss: 0.6870 - learning_rate: 0.0010
# Epoch 4/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.5549 - loss: 0.6864 - val_accuracy: 0.5807 - val_loss: 0.6825 - learning_rate: 0.0010
# Epoch 5/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 721ms/step - accuracy: 0.5632 - loss: 0.6925 - val_accuracy: 0.4920 - val_loss: 0.8646 - learning_rate: 0.0010
# Epoch 6/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 720ms/step - accuracy: 0.5084 - loss: 0.7418 - val_accuracy: 0.5222 - val_loss: 0.6928 - learning_rate: 0.0010
# Epoch 7/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 726ms/step - accuracy: 0.5403 - loss: 0.6979 - val_accuracy: 0.6077 - val_loss: 0.6627 - learning_rate: 0.0010
# Epoch 8/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 735ms/step - accuracy: 0.6182 - loss: 0.6485 - val_accuracy: 0.6790 - val_loss: 0.6021 - learning_rate: 0.0010
# Epoch 9/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 734ms/step - accuracy: 0.6609 - loss: 0.6165 - val_accuracy: 0.6593 - val_loss: 0.6005 - learning_rate: 0.0010
# Epoch 10/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 737ms/step - accuracy: 0.6717 - loss: 0.6053 - val_accuracy: 0.6988 - val_loss: 0.5792 - learning_rate: 0.0010
# Epoch 11/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 727ms/step - accuracy: 0.6744 - loss: 0.6012 - val_accuracy: 0.6965 - val_loss: 0.6007 - learning_rate: 0.0010
# Epoch 12/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 719ms/step - accuracy: 0.6755 - loss: 0.6024 - val_accuracy: 0.6795 - val_loss: 0.5919 - learning_rate: 0.0010
# Epoch 13/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.6689 - loss: 0.6064 - val_accuracy: 0.7067 - val_loss: 0.5705 - learning_rate: 0.0010
# Epoch 14/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 732ms/step - accuracy: 0.6867 - loss: 0.5847 - val_accuracy: 0.6840 - val_loss: 0.5938 - learning_rate: 0.0010
# Epoch 15/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 726ms/step - accuracy: 0.6734 - loss: 0.6013 - val_accuracy: 0.6690 - val_loss: 0.6082 - learning_rate: 0.0010
# Epoch 16/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 720ms/step - accuracy: 0.6872 - loss: 0.5899 - val_accuracy: 0.7185 - val_loss: 0.5578 - learning_rate: 0.0010
# Epoch 17/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 723ms/step - accuracy: 0.7054 - loss: 0.5668 - val_accuracy: 0.7310 - val_loss: 0.5364 - learning_rate: 0.0010
# Epoch 18/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 723ms/step - accuracy: 0.7033 - loss: 0.5676 - val_accuracy: 0.6245 - val_loss: 0.6219 - learning_rate: 0.0010
# Epoch 19/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 719ms/step - accuracy: 0.7057 - loss: 0.5654 - val_accuracy: 0.6935 - val_loss: 0.5740 - learning_rate: 0.0010
# Epoch 20/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 723ms/step - accuracy: 0.7007 - loss: 0.5717 - val_accuracy: 0.7387 - val_loss: 0.5323 - learning_rate: 0.0010
# Epoch 21/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 726ms/step - accuracy: 0.7134 - loss: 0.5542 - val_accuracy: 0.7272 - val_loss: 0.5360 - learning_rate: 0.0010
# Epoch 22/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 728ms/step - accuracy: 0.7158 - loss: 0.5531 - val_accuracy: 0.7358 - val_loss: 0.5321 - learning_rate: 0.0010
# Epoch 23/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 720ms/step - accuracy: 0.7218 - loss: 0.5465 - val_accuracy: 0.7280 - val_loss: 0.5389 - learning_rate: 0.0010
# Epoch 24/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 722ms/step - accuracy: 0.7055 - loss: 0.5616 - val_accuracy: 0.7380 - val_loss: 0.5311 - learning_rate: 0.0010
# Epoch 25/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 725ms/step - accuracy: 0.7198 - loss: 0.5471 - val_accuracy: 0.7280 - val_loss: 0.5416 - learning_rate: 0.0010
# Epoch 26/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 722ms/step - accuracy: 0.7188 - loss: 0.5467 - val_accuracy: 0.7370 - val_loss: 0.5268 - learning_rate: 0.0010
# Epoch 27/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 718ms/step - accuracy: 0.7194 - loss: 0.5498 - val_accuracy: 0.7377 - val_loss: 0.5268 - learning_rate: 0.0010
# Epoch 28/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 725ms/step - accuracy: 0.7137 - loss: 0.5557 - val_accuracy: 0.7368 - val_loss: 0.5309 - learning_rate: 0.0010
# Epoch 29/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 718ms/step - accuracy: 0.7254 - loss: 0.5407 - val_accuracy: 0.7420 - val_loss: 0.5236 - learning_rate: 0.0010
# Epoch 30/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 719ms/step - accuracy: 0.7242 - loss: 0.5402 - val_accuracy: 0.7398 - val_loss: 0.5269 - learning_rate: 0.0010

# %% [markdown]
# ### Questions:
# - Describe the conditions that will lead the learning rate to be reduced, given our settings above.
# - Did the automated loss rate reduction we applied kick in during training? If yes, how many times was a reduction in loss rate applied?
# - Describe the conditions that will lead to early stopping, given our settings above.
# - Did early stopping kick in during training?

# %% [markdown]
# >The learning rate will be reduced when val_loss doesn't improve by at least 0.0005 over 5 epochs
#
# >No. The automated loss rate reduction did not kick in during training.
#
# >Early stopping will happen when val_loss doesn't improve by 0.0001 over 10 epochs.
#
# >No. Early stopping did not kick in during training.

# %% [markdown]
# Now that the model is trained, let's see the results on the test data. This will also take a little time, since evalaution in RNN's also happens sequentially. On my laptop, it took 2 minutes.

# %%
model_rnn.evaluate(x_test[...,np.newaxis], y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 117s 372ms/step - accuracy: 0.7267 - loss: 0.5411
# [0.541050910949707, 0.7267000079154968]

# %% [markdown]
# ### Plot loss and accuracy

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results_rnn.history['loss'])
plt.plot(results_rnn.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(results_rnn.history['accuracy'])
plt.plot(results_rnn.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Questions:
# - Did the model converge?
# - Does the model have high bias, high variance, both, or neither?
# - How well does our model perform on the test data?
# - What would you suggest we try to improve the model performance?

# %% [markdown]
# >The model didn't converge as evidenced by the lack of a plateau.
#
# >There is high bias. The training and validation accuracy are similar but end near 0.75 which is relatively low.
#
# >The model performs pretty poorly with an accuracy of 0.727.
#
# >We should try more layers to try to improve the model performance.

# %% [markdown]
# # These two networks take longer to train. I suggest each group member train one of them in studio, and then you can compare your results.
# If you have extra time, you can go back and train the one you skipped.
#
#
# ## RNN 2: Bidirectional RNN

# %%
model_birnn = Sequential()
model_birnn.add(keras.Input(shape=(500, 1)))
model_birnn.add(Bidirectional(SimpleRNN(32, return_sequences=True, recurrent_initializer="glorot_uniform")))
#model_rnn.add(Bidirectional(SimpleRNN(64, return_sequences=True, recurrent_initializer="glorot_uniform")))
model_birnn.add(Bidirectional(SimpleRNN(10, return_sequences=True, recurrent_initializer="glorot_uniform")))
model_birnn.add(Flatten())
model_birnn.add(Dropout(0.3))
model_birnn.add(Dense(1, activation="sigmoid"))

model_birnn.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_2 (Bidirectional) │ (None, 500, 64)        │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 500, 20)        │         1,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 10000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 10000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │        10,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,677 (53.43 KB)
#  Trainable params: 13,677 (53.43 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Questions:
# - How many hidden layers does this model have?
# - How many free parameters?
# - Why does this model have more parameters than our first RNN model?

# %% [markdown]
# >There are 2 hidden laters in this model.
#
# >There are 13,677 free parameters.
#
# >This model has more parameters than oru first RNN model because the layers are bidirectional and therefore have about 2x the number of parameters.

# %% [markdown]
# ### Compile and fit the model
#
# With more parameters, this model takes longer to train! We're training 4 RNNs here, not 2: for each RNN layer, we train one that moves forward through the sequence and one that moves backward through the sequence.
#
# For me, this network took ~1m per epoch to train, so about 30 mins in total.
#
# Feel free to have an project group check-in discussion while your networks train.

# %%
model_birnn.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.AdamW(1e-3, weight_decay=0.00008),
    metrics=['accuracy'])

# %%
results_birnn = model_birnn.fit(x_train[...,np.newaxis], y_train,
                    batch_size=1024,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1,
                    callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
                                 keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
                    )
# Out:
# Epoch 1/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.5231 - loss: 0.7161 - val_accuracy: 0.6202 - val_loss: 0.6464 - learning_rate: 0.0010
# Epoch 2/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.6527 - loss: 0.6590 - val_accuracy: 0.4960 - val_loss: 1.7568 - learning_rate: 0.0010
# Epoch 3/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.5071 - loss: 0.8477 - val_accuracy: 0.5625 - val_loss: 0.6770 - learning_rate: 0.0010
# Epoch 4/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6166 - loss: 0.6493 - val_accuracy: 0.6765 - val_loss: 0.5995 - learning_rate: 0.0010
# Epoch 5/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6617 - loss: 0.6364 - val_accuracy: 0.6898 - val_loss: 0.5923 - learning_rate: 0.0010
# Epoch 6/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6627 - loss: 0.6165 - val_accuracy: 0.7040 - val_loss: 0.5815 - learning_rate: 0.0010
# Epoch 7/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6744 - loss: 0.6258 - val_accuracy: 0.6562 - val_loss: 0.6181 - learning_rate: 0.0010
# Epoch 8/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6469 - loss: 0.6306 - val_accuracy: 0.5953 - val_loss: 0.6716 - learning_rate: 0.0010
# Epoch 9/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6481 - loss: 0.6270 - val_accuracy: 0.6948 - val_loss: 0.5920 - learning_rate: 0.0010
# Epoch 10/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6783 - loss: 0.5989 - val_accuracy: 0.6643 - val_loss: 0.6082 - learning_rate: 0.0010
# Epoch 11/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6863 - loss: 0.5938 - val_accuracy: 0.7138 - val_loss: 0.5652 - learning_rate: 0.0010
# Epoch 12/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.6950 - loss: 0.5831 - val_accuracy: 0.7190 - val_loss: 0.5578 - learning_rate: 0.0010
# Epoch 13/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7023 - loss: 0.5748 - val_accuracy: 0.7280 - val_loss: 0.5479 - learning_rate: 0.0010
# Epoch 14/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7028 - loss: 0.5761 - val_accuracy: 0.6750 - val_loss: 0.5963 - learning_rate: 0.0010
# Epoch 15/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7009 - loss: 0.5774 - val_accuracy: 0.7138 - val_loss: 0.5630 - learning_rate: 0.0010
# Epoch 16/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7060 - loss: 0.5710 - val_accuracy: 0.7222 - val_loss: 0.5506 - learning_rate: 0.0010
# Epoch 17/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7175 - loss: 0.5577 - val_accuracy: 0.7120 - val_loss: 0.5628 - learning_rate: 0.0010
# Epoch 18/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7103 - loss: 0.5607
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7119 - loss: 0.5593 - val_accuracy: 0.6388 - val_loss: 0.6079 - learning_rate: 0.0010
# Epoch 19/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7102 - loss: 0.5641 - val_accuracy: 0.7365 - val_loss: 0.5347 - learning_rate: 5.0000e-04
# Epoch 20/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7235 - loss: 0.5492 - val_accuracy: 0.7420 - val_loss: 0.5313 - learning_rate: 5.0000e-04
# Epoch 21/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7246 - loss: 0.5463 - val_accuracy: 0.7185 - val_loss: 0.5521 - learning_rate: 5.0000e-04
# Epoch 22/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7244 - loss: 0.5483 - val_accuracy: 0.7390 - val_loss: 0.5300 - learning_rate: 5.0000e-04
# Epoch 23/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7161 - loss: 0.5561 - val_accuracy: 0.7188 - val_loss: 0.5527 - learning_rate: 5.0000e-04
# Epoch 24/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7204 - loss: 0.5520 - val_accuracy: 0.7393 - val_loss: 0.5329 - learning_rate: 5.0000e-04
# Epoch 25/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7227 - loss: 0.5445 - val_accuracy: 0.7300 - val_loss: 0.5370 - learning_rate: 5.0000e-04
# Epoch 26/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7238 - loss: 0.5452 - val_accuracy: 0.7222 - val_loss: 0.5472 - learning_rate: 5.0000e-04
# Epoch 27/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7209 - loss: 0.5497
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7203 - loss: 0.5500 - val_accuracy: 0.7293 - val_loss: 0.5406 - learning_rate: 5.0000e-04
# Epoch 28/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.7298 - loss: 0.5378 - val_accuracy: 0.7425 - val_loss: 0.5284 - learning_rate: 2.5000e-04
# Epoch 29/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7294 - loss: 0.5381 - val_accuracy: 0.7423 - val_loss: 0.5283 - learning_rate: 2.5000e-04
# Epoch 30/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7283 - loss: 0.5392 - val_accuracy: 0.7305 - val_loss: 0.5344 - learning_rate: 2.5000e-04

# %% [markdown]
# ### Questions:
# - Did the automated loss rate reduction we applied kick in during training? If yes, how many times was a reduction in loss rate applied?
# - Did early stopping kick in during training?

# %% [markdown]
# >The automated loss rate reduction kicked in during training twice.
#
# >Early stopping did not kick in during training.

# %% [markdown]
# Now that the model is trained, let's see the results on the test data. This will also take a little time, since evalaution in RNN's also happens sequentially. On my laptop, it took 2 minutes.

# %%
model_birnn.evaluate(x_test[...,np.newaxis], y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 225s 717ms/step - accuracy: 0.7261 - loss: 0.5448
# [0.5447633862495422, 0.7261000275611877]

# %% [markdown]
# ### Plot loss and accuracy

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results_birnn.history['loss'])
plt.plot(results_birnn.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(results_birnn.history['accuracy'])
plt.plot(results_birnn.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Questions:
# - Did the model converge?
# - Does the model have high bias, high variance, both, or neither?
# - How well does our model perform on the test data?
# - What would you suggest we try to improve the model performance?

# %% [markdown]
# >Yes. The model appears to converge.
#
# >the model has high bias. The training and validation accuracy is about 0.73.
#
# >The model performs poorly on the test data.
#
# >We should add more hidden layers to the model to improve the performance.

# %% [markdown]
# ## RNN 3: LSTM
#
# This time, we'll try a relatively shallow uni-directional LSTM for comparison.

# %%
model_lstm = Sequential()
model_lstm.add(keras.Input(shape=(500, 1)))
model_lstm.add(LSTM(32, return_sequences=True, recurrent_initializer="glorot_uniform"))
#model_lstm.add(LSTM(64, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_lstm.add(LSTM(10, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_lstm.add(Flatten())
model_lstm.add(Dropout(0.3))
model_lstm.add(Dense(1, activation="sigmoid"))

model_lstm.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 500, 32)        │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 500, 10)        │         1,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 5000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 5000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │         5,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,073 (43.25 KB)
#  Trainable params: 11,073 (43.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Questions:
# - How many hidden layers does this model have?
# - How many free parameters?

# %% [markdown]
# >There are 2 hidden layers.
#
# >There are 11,073 free parameters.

# %% [markdown]
# #### LSTM Training

# %%
model_lstm.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.AdamW(1e-3, weight_decay=0.00008),
    metrics=['accuracy'])

# %% [markdown]
# More parameters mean longer training times: this one took ~1m per epoch on my laptop, about 28 minutes in total.
#
# Feel free to have an project group check-in discussion while your networks train.

# %%
results_lstm = model_lstm.fit(x_train[...,np.newaxis], y_train,
                    batch_size=1024,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1,
                    callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
                                 keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
                    )
# Out:
# Epoch 1/30
# 24/36 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5500 - loss: 0.6848
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 results_lstm = model_lstm.fit(x_train[...,np.newaxis], y_train,
#       2                     batch_size=1024,
#       3                     epochs=30,
#       4                     verbose=1,
#       5                     validation_split=0.1,
#       6                     callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
#       7                                  keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
#       8                     )
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/backend/torch/trainer.py:269, in TorchTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     265 for begin_step, end_step, data in epoch_iterator:
#     266     # Callbacks
#     267     callbacks.on_train_batch_begin(begin_step)
# --> 269     logs = self.train_function(data)
#     271     # Callbacks
#     272     callbacks.on_train_batch_end(end_step, logs)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/backend/torch/trainer.py:124, in TorchTrainer.make_train_function.<locals>.one_step_on_data(data)
#     122 """Runs a single training step on a batch of data."""
#     123 data = data[0]
# --> 124 return self.train_step(data)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/backend/torch/trainer.py:45, in TorchTrainer.train_step(self, data)
#      43 # Compute predictions
#      44 if self._call_has_training_arg:
# ---> 45     y_pred = self(x, training=True)
#      46 else:
#      47     y_pred = self(x)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/layers/layer.py:941, in Layer.__call__(self, *args, **kwargs)
#     939         outputs = super().__call__(*args, **kwargs)
#     940 else:
# --> 941     outputs = super().__call__(*args, **kwargs)
#     942 # Change the layout for the layer output if needed.
#     943 # This is useful for relayout intermediate tensor in the model
#     944 # to achieve the optimal performance.
#     945 distribution = distribution_lib.distribution()
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/backend/torch/layer.py:41, in TorchLayer.forward(self, *args, **kwargs)
#      40 def forward(self, *args, **kwargs):
# ---> 41     return Operation.__call__(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/ops/operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/models/sequential.py:220, in Sequential.call(self, inputs, training, mask, **kwargs)
#     218 def call(self, inputs, training=None, mask=None, **kwargs):
#     219     if self._functional:
# --> 220         return self._functional.call(
#     221             inputs, training=training, mask=mask, **kwargs
#     222         )
#     224     # Fallback: Just apply the layer sequence.
#     225     # This typically happens if `inputs` is a nested struct.
#     226     for layer in self.layers:
#     227         # During each iteration, `inputs` are the inputs to `layer`, and
#     228         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     229         # end of each iteration `inputs` is set to `outputs` to prepare for
#     230         # the next layer.
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/models/functional.py:183, in Functional.call(self, inputs, training, mask, **kwargs)
#     181         if mask is not None:
#     182             backend.set_keras_mask(x, mask)
# --> 183 outputs = self._run_through_graph(
#     184     inputs,
#     185     operation_fn=lambda op: operation_fn(
#     186         op, training=training, **kwargs
#     187     ),
#     188 )
#     189 return unpack_singleton(outputs)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/ops/function.py:206, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     204     operation = self._get_operation_for_node(node)
#     205     op = operation_fn(operation)
# --> 206     outputs = op(*args, **kwargs)
#     208 # Update tensor_dict.
#     209 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/models/functional.py:644, in operation_fn.<locals>.call(*args, **kwargs)
#     638     if (
#     639         name in getattr(operation, "_call_context_args", {})
#     640         and value is not None
#     641     ):
#     642         kwargs[name] = value
# --> 644 return operation(*args, **kwargs)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/layers/layer.py:941, in Layer.__call__(self, *args, **kwargs)
#     939         outputs = super().__call__(*args, **kwargs)
#     940 else:
# --> 941     outputs = super().__call__(*args, **kwargs)
#     942 # Change the layout for the layer output if needed.
#     943 # This is useful for relayout intermediate tensor in the model
#     944 # to achieve the optimal performance.
#     945 distribution = distribution_lib.distribution()
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/backend/torch/layer.py:41, in TorchLayer.forward(self, *args, **kwargs)
#      40 def forward(self, *args, **kwargs):
# ---> 41     return Operation.__call__(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/ops/operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/layers/rnn/lstm.py:583, in LSTM.call(self, sequences, initial_state, mask, training)
#     582 def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 583     return super().call(
#     584         sequences, mask=mask, training=training, initial_state=initial_state
#     585     )
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:425, in RNN.call(self, sequences, initial_state, mask, training)
#     419 # Prepopulate the dropout state so that the inner_loop is stateless
#     420 # this is particularly important for JAX backend.
#     421 self._maybe_config_dropout_masks(
#     422     self.cell, sequences[:, 0, :], initial_state
#     423 )
# --> 425 last_output, outputs, states = self.inner_loop(
#     426     sequences=sequences,
#     427     initial_state=initial_state,
#     428     mask=mask,
#     429     training=training,
#     430 )
#     431 last_output = ops.cast(last_output, self.compute_dtype)
#     432 outputs = ops.cast(outputs, self.compute_dtype)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/layers/rnn/lstm.py:578, in LSTM.inner_loop(self, sequences, initial_state, mask, training)
#     571 if self.use_cudnn is True:
#     572     raise ValueError(
#     573         "use_cudnn=True was specified, "
#     574         "but cuDNN is not supported for this layer configuration "
#     575         "with this backend. Pass use_cudnn='auto' to fallback "
#     576         "to a non-cuDNN implementation."
#     577     )
# --> 578 return super().inner_loop(
#     579     sequences, initial_state, mask=mask, training=training
#     580 )
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:350, in RNN.inner_loop(self, sequences, initial_state, mask, training)
#     347 if not tree.is_nested(initial_state):
#     348     initial_state = [initial_state]
# --> 350 return backend.rnn(
#     351     step,
#     352     sequences,
#     353     initial_state,
#     354     go_backwards=self.go_backwards,
#     355     mask=mask,
#     356     unroll=self.unroll,
#     357     input_length=sequences.shape[1],
#     358     zero_output_for_mask=self.zero_output_for_mask,
#     359     return_all_outputs=self.return_sequences,
#     360 )
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/backend/torch/rnn.py:353, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     351 new_states = states
#     352 while time < time_steps_t and it < max_iterations:
# --> 353     final_outputs = _step(time, output_ta_t, *new_states)
#     354     time, output_ta_t = final_outputs[:2]
#     355     new_states = final_outputs[2:]
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/backend/torch/rnn.py:334, in rnn.<locals>._step(time, output_ta_t, *states)
#     332 current_input = tuple(ta[time] for ta in input_ta)
#     333 current_input = tree.pack_sequence_as(inputs, current_input)
# --> 334 output, new_states = step_function(
#     335     current_input, tuple(states) + tuple(constants)
#     336 )
#     337 flat_new_state = tree.flatten(new_states)
#     339 flat_output = tree.flatten(output)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:342, in RNN.inner_loop.<locals>.step(inputs, states)
#     340 if backend.backend() == "torch" and self.stateful:
#     341     states = tree.map_structure(ops.copy, states)
# --> 342 output, new_states = self.cell(inputs, states, **cell_kwargs)
#     343 if not tree.is_nested(new_states):
#     344     new_states = [new_states]
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/layers/layer.py:969, in Layer.__call__(self, *args, **kwargs)
#     965     if self.supports_masking:
#     966         self._set_mask_metadata(
#     967             call_spec.first_arg, outputs, previous_mask
#     968         )
# --> 969     elif any(m is not None for m in tree.flatten(previous_mask)):
#     970         warnings.warn(
#     971             f"Layer '{self.name}' (of type {self.__class__.__name__}) "
#     972             "was passed an input with a mask attached to it. "
#    (...)    975             "layers will not see the mask."
#     976         )
#     977 finally:
#     978     # Destroy call context if we created it
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/tree/tree_api.py:138, in flatten(structure)
#     108 @keras_export("keras.tree.flatten")
#     109 def flatten(structure):
#     110     """Flattens a possibly nested structure into a list.
#     111
#     112     In the case of dict instances, the sequence consists of the values,
#    (...)    136         A list, the flattened version of the input `structure`.
#     137     """
# --> 138     return tree_impl.flatten(structure)
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/tree/torchtree_impl.py:94, in flatten(structure)
#      91 def flatten(structure):
#      92     # We need to first sort dicts to ensure a deterministic order that is
#      93     # consistent with other tree implementations.
# ---> 94     structure = _dict_to_ordered_dict(structure)
#      95     leaves, _ = torch_tree.tree_flatten(structure)
#      96     return leaves
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/tree/torchtree_impl.py:51, in _dict_to_ordered_dict(structure)
#      49 ret = func(structure)
#      50 if ret is None:
# ---> 51     return traverse_children()
#      52 if isinstance(ret, type) and ret.__name__ == "MAP_TO_NONE":
#      53     return None
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/keras/src/tree/torchtree_impl.py:37, in _dict_to_ordered_dict.<locals>.traverse_children()
#      36 def traverse_children():
# ---> 37     children, treedef = torch_tree.tree_flatten(
#      38         structure,
#      39         is_leaf=lambda x: x is not structure,
#      40     )
#      41     if treedef.num_nodes == 1 and treedef.num_leaves == 1:
#      42         return structure
#
# File /opt/anaconda3/envs/phy448_deeplearning/lib/python3.12/site-packages/torch/utils/_pytree.py:893, in tree_flatten(tree, is_leaf)
#     886     children_specs = [
#     887         _tree_flatten_helper(child, leaves, is_leaf=is_leaf) for child in child_pytrees
#     888     ]
#     890     return TreeSpec(node_type, context, children_specs)
# --> 893 def tree_flatten(
#     894     tree: PyTree,
#     895     is_leaf: Optional[Callable[[PyTree], bool]] = None,
#     896 ) -> Tuple[List[Any], TreeSpec]:
#     897     """Flattens a pytree into a list of values and a TreeSpec that can be used
#     898     to reconstruct the pytree.
#     899     """
#     900     leaves: List[Any] = []
#
# KeyboardInterrupt:

# %% [markdown]
# ### Questions:
# - Did the automated loss rate reduction we applied kick in during training? If yes, how many times was a reduction in loss rate applied?
# - Did early stopping kick in during training?

# %%
model_lstm.evaluate(x_test[...,np.newaxis], y_test)

# %% [markdown]
# ### Plot loss and accuracy

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results_lstm.history['loss'])
plt.plot(results_lstm.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(results_lstm.history['accuracy'])
plt.plot(results_lstm.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Questions:
# - Did the model converge?
# - Does the model have high bias, high variance, both, or neither?
# - How well does our model perform on the test data?
# - What would you suggest we try to improve the model performance?

# %% [markdown]
# ### Conclusion Questions:
# - Based on the 3 networks, does adding more information about long-term correlations in the signal improve performance? Which networks should you compare to evaluate this? Connect your discussion to the cosmic ray signal shape you observed during the initial data exploration.
# - Based on the 3 networks, does adding more information about backwards-running correlations in the signal improve performance? Which networks should you compare to evaluate this? Connect your discussion to the cosmic ray signal shape you observed during the initial data exploration.
# - Can we conclude that for this task, LSTMs and bi-directionality won't ever help? Or are there other changes we should make before re-evaluating those questions? If so, describe the changes you'd suggest.

# %% [markdown]
# ### Acknowledgement Statement:

# %% [markdown]
# After that, you're done with studio for today! Upload your notebook to Gradescope, making sure to merge the written responses for all 3 RNNs into a single notebook, even if all 3 weren't trained in that notebook.

# %% [markdown]
# # Studio 14: Finding Cosmic Ray Signals with RNNs
#
# Adapted from https://deeplearningforphysicsresearchbook.github.io/deep-learning-physics/ by Javier Duarte (2023)
#
# Further modifications by Julieta Gruszko (2025)
#
# Large arrays of radio antennas can be used to measure cosmic rays by recording the electromagnetic radiation generated in the atmosphere.
# These radio signals are strongly contaminated by galactic noise as well as signals from human origin. Since these signals appear to be similar to the background, the discovery of cosmic-ray events can be challenging.
#
# The data file for this studio is a bit too large to host on Github. It's available on Canvas instead, go ahead and download it from there.
#
# ## Identification of signals
# In this exercise, we design an RNN to classify if the recorded radio signals contain a cosmic-ray event or only noise.
#
# The signal-to-noise ratio (SNR) of a measured trace $S(t)$ is defined as follows:
#
# $SNR=\frac{|S(t)_{max}|}{RMS[S(t)]}$
#
# where $|S(t)_{max}|$ denotes the maximum amplitude of the (true) signal.
#
# Typical cosmic-ray observatories enable a precise reconstruction at an SNR of roughly 3.
#
# We choose a challenging setup in this task and try to identify cosmic-ray events in signal traces with an SNR of 2.

# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler

import matplotlib
import matplotlib.pyplot as plt

import torch as torch
import torch.nn as nn

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

# %% [markdown]
# Training RNNs can be computationally demanding, thus, we recommend to use a GPU for this task if possible.
# ### Depending on your computer, you should run just one of the two options below to switch to GPU, if available.

# %% [markdown]
# ### For Macs:
# If you have an Apple Silicon chip in your laptop (e.g. M1 or above), you can use the integrated GPU by running the code below.

# %%
# !xcode-select --install
# Out:
# xcode-select: note: Command line tools are already installed. Use "Software Update" in System Settings or the softwareupdate command line interface to install updates

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple GPU with Metal backend.")
else:
    device = torch.device("cpu")
    print("Using CPU.")
# Out:
# Using Apple GPU with Metal backend.

# %% [markdown]
# ### For Others:
# If you have a non-Mac computer, you can check for an available GPU with by running this code:

# %%
if torch.cuda.is_available():
    print("GPU is available for PyTorch.")
    print(f"Number of GPUs available: {torch.cuda.device_count()}")
    print(f"Current GPU device name: {torch.cuda.get_device_name(0)}") # Get name of the first GPU
else:
    print("GPU is NOT available for PyTorch. Using CPU.")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import keras

from keras import Input

from keras.models import Sequential #the model is built adding layers one after the other

from keras.layers import Dense #fully connected layers: every output talks to every input

from keras.layers import Activation

from keras.layers import SimpleRNN, LSTM, Bidirectional, Flatten, Dropout

# %% [markdown]
# ### Load and prepare dataset
# In this task, we use a simulation of cosmic-ray-induced air showers that are measured by radion antennas.
# For more information, see https://arxiv.org/abs/1901.04079.
# The task is to design an RNN which is able to identify if the measured signal traces (shortened to 500 time steps) contains a signal or not.

# %%
f = np.load("../Data/cosmic-radio-showers_with_signals.npz")

# %% [markdown]
# The file contains measured traces, labels, and for cosmic-ray events, the true signal. For non cosmic-ray events, the signal object is set to 0. The traces and signals are each 500 samples long.

# %%
f.files
# Out:
# ['traces', 'labels', 'signals']

# %% [markdown]
# ## Plot example signal traces
# Left: signal trace containing a cosmic-ray event. The underlying cosmic-ray signal is shown in red, the backgrounds + signal is shown in blue.
# Right: background noise, with 0 underlying signal trace.

# %%
from matplotlib import pyplot as plt
fs = 180e6  # Sampling frequency of antenna setup 180 MHz
t = np.arange(500) / fs * 1e6
idx_sig = 54 #pick the n'th signal trace in the file
idx_noise = 17 #pick the n'th noise trace in the file

plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(t, np.real(f["traces"][np.where(f["labels"] == 1)][idx_sig]), linewidth = 1, color="b", label="Measured trace")
plt.plot(t, np.real(f["signals"][np.where(f["labels"] == 1)][idx_sig]), linewidth = 1, color="r", label="CR signal")
plt.ylabel('Amplitude / mV')
plt.xlabel('Time / $\mu$ s')
plt.legend()
plt.title("Cosmic-ray event")
plt.subplot(1, 2, 2)

plt.plot(t, np.real(f["traces"][np.where(f["labels"] == 0)][idx_noise]), linewidth = 1, color="b", label="Measured trace")
plt.plot(t, np.real(f["signals"][np.where(f["labels"] == 0)][idx_noise]), linewidth = 1, color="r", label="CR signal")

plt.ylabel('Amplitude / mV')
plt.xlabel('Time / $\mu$ s')
plt.legend()
plt.title("Noise event")

plt.grid(True)
plt.tight_layout()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/jr/svbnrsxx2gddc8x3xhz_57b40000gn/T/ipykernel_23040/2179829671.py:12: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Time / $\mu$ s')
# /var/folders/jr/svbnrsxx2gddc8x3xhz_57b40000gn/T/ipykernel_23040/2179829671.py:21: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Time / $\mu$ s')

# %%
np.shape(f['traces'])
# Out:
# (50000, 500)

# %%
print(np.shape(f['labels'][f['labels']==1])) # cosmic ray events
print(np.shape(f['labels'][f['labels']==0])) # noise events
# Out:
# (25078,)
# (24922,)

# %% [markdown]
# ### Questions:
# - How many instances are in our learning set?
# - Is the data set balanced or unbalanced?
# - In this notebook, we'll try to identify whether a signal is present in each trace. When type of RNN structure do we need to use? E.g. sequence-to-sequence, vector-to-sequence, or sequence-to-vector?
# - What type of task are we performing (e.g. classification, regression, generation)? What type of activation function should our final layer use? What type of loss should we optimize?

# %% [markdown]
# >There are about 50,000 instances in our learning set.
#
# >The data set is balanced. There are 25,078 instances of cosmic ray events and 24,922 instances of noise events.
#
# >We need to use a sequence-to-vector RNN structure.
#
# >We are performing a classification task (identifying whether a signal is present in each trace). We should use a sigmoid activation function for the final layer and binary cross entropy for the loss function.

# %% [markdown]
# As we did last week, we will use sk-learn's $\texttt{train\_test\_split}$ to split the data in to random selections with appropriate fractions. This time, instead of making a validation set ourselves, we'll use Keras's built-in validation split option. We'll just split off test data for now.

# %%
# split the samples into training and test data sets:
train_frac = 0.8
test_frac = 0.2

x_train, x_test, y_train, y_test = train_test_split(
    f["traces"], f['labels'], test_size=test_frac, random_state=42
)

# %% [markdown]
# ### Scaling
# Let's scale the data so that the train data traces have standard deviation of 1. We won't bother shifting the mean, since the data traces are already centered around 0. We could use sk-learn's Standard Scaler object to do this, but it's also easy enough to do it by hand.

# %%
sigma = x_train.std()
x_train /= sigma
x_test /= sigma

# %%
x_train.std()
# Out:
# np.float32(1.0000002)

# %% [markdown]
# ### Define RNN model
# In the following, design a cosmic-ray model to identify cosmic-ray events using an RNN-based classifier.
#
# We'll start with a Simple RNN, then try a bi-directional RNN, then finally a one-direction LSTM.
#
# By default, the output of an RNN layer contains a single vector per sample. This vector is the RNN cell output corresponding to the last timestep, containing information about the entire input sequence. The shape of this output is $\texttt{(batch\_size, units)}$ where $\texttt{units}$ corresponds to the units argument passed to the layer's constructor.
#
# A RNN layer can also return the entire sequence of outputs for each sample (one vector per timestep per sample), if you set $\texttt{return\_sequences=True}$. The shape of this output is $\texttt{(batch\_size, timesteps, units)}$.
#
# $\texttt{return\_sequences=True}$ is used when you want to return a sequence (e.g. one-to-many and many-to-many RNNs). When you're stacking RNN layers, as we do below, each RNN layer is expecting a sequence as an input, so you'll want to keep it set to $\texttt{True}$. In the final RNN layer for a many-to-one RNN, we can choose: either we can either use an RNN layer as the last step, setting it to $\texttt{False}$ to return a single value, or we can output the sequence from our last RNN layer, sending it to a fully connected layer with a single output for the last step.
#
#
# ## RNN 1: Simple RNN
#
# This model is probably a bit too shallow to perform really well, but we'll keep it simple to reduce the training time to something that can be done in class. The commented-out layer can be reintroduced if you want to try something deeper later on.

# %%
model_rnn = Sequential()
model_rnn.add(keras.Input(shape=(500, 1)))
model_rnn.add(SimpleRNN(32, return_sequences=True, recurrent_initializer="glorot_uniform"))
#model_rnn.add(SimpleRNN(64, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_rnn.add(SimpleRNN(10, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_rnn.add(Flatten())
model_rnn.add(Dropout(0.3))
model_rnn.add(Dense(1, activation="sigmoid"))

model_rnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 500, 32)        │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 500, 10)        │           430 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 5000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         5,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,519 (25.46 KB)
#  Trainable params: 6,519 (25.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Questions:
# - How many hidden layers does this model have?
# - How many free parameters?

# %% [markdown]
# >This model has 2 hidden layers (simple_rnn, simple_rnn_1)
#
# >There are 6,519 free parameters.

# %% [markdown]
# ### Compile the model
#
# We'll use AdamW, our old standby optimizer. This time we'll set the $\texttt{weight\_decay}$ option to a smaller value than the default; this parameter controls how strong the regularization is.

# %%
model_rnn.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.AdamW(1e-3, weight_decay=0.00008),
    metrics=['accuracy'])

# %% [markdown]
# ### Fitting the model on GPU
#
# To actually run the training on GPU, we'll need to explicitly move the data over to the GPU. Once the data is on GPU, Keras automatically handles sending the model to GPU for training. To move the data over, we first need to switch it from a numpy array to a torch tensor.
#
# If you ran the right cells above, $\texttt{device}$ should be set correctly for your computer (CPU if you don't have a GPU, or the appropriate GPU options for Macs or non-Macs).

# %%
x_train = torch.from_numpy(x_train)
x_train = x_train.to(device)

y_train = torch.from_numpy(y_train)
y_train = y_train.to(device)

x_test = torch.from_numpy(x_test)
x_test = x_test.to(device)

y_test = torch.from_numpy(y_test)
y_test = y_test.to(device)

# %% [markdown]
# For the fit, we're going to use a couple of new options that should help the optimization process avoid some of the pitfalls we saw last week:
# - Reduce the learning rate when the loss stops improving, so your optimizer takes smaller steps when it's getting close to the minimum.
# - Apply early stopping, so training stops if the loss doesn't improve after some number of generations.
#
# Even using a GPU, training RNN's is very slow: they need to process samples one at a time. On my laptop (using an M2 GPU) this model took about 26 seconds per epoch to train; about 13 minutes in total.
#
# 30 epochs is probably a bit short, but it should be close enough while keeping to our time constraints.

# %%
results_rnn = model_rnn.fit(x_train[...,np.newaxis], y_train,
                    batch_size=1024,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1,
                    callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
                                 keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
                    )
# Out:
# Epoch 1/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 28s 750ms/step - accuracy: 0.5040 - loss: 0.7179 - val_accuracy: 0.5612 - val_loss: 0.6824 - learning_rate: 0.0010
# Epoch 2/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.6007 - loss: 0.6621 - val_accuracy: 0.6975 - val_loss: 0.6030 - learning_rate: 0.0010
# Epoch 3/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.6601 - loss: 0.6186 - val_accuracy: 0.7262 - val_loss: 0.5607 - learning_rate: 0.0010
# Epoch 4/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 735ms/step - accuracy: 0.6891 - loss: 0.5944 - val_accuracy: 0.7337 - val_loss: 0.5507 - learning_rate: 0.0010
# Epoch 5/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 731ms/step - accuracy: 0.6978 - loss: 0.5829 - val_accuracy: 0.7100 - val_loss: 0.5649 - learning_rate: 0.0010
# Epoch 6/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 757ms/step - accuracy: 0.6919 - loss: 0.5903 - val_accuracy: 0.6323 - val_loss: 0.6508 - learning_rate: 0.0010
# Epoch 7/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 737ms/step - accuracy: 0.6985 - loss: 0.5811 - val_accuracy: 0.7440 - val_loss: 0.5393 - learning_rate: 0.0010
# Epoch 8/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 719ms/step - accuracy: 0.7045 - loss: 0.5717 - val_accuracy: 0.7427 - val_loss: 0.5385 - learning_rate: 0.0010
# Epoch 9/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 719ms/step - accuracy: 0.7056 - loss: 0.5734 - val_accuracy: 0.7450 - val_loss: 0.5330 - learning_rate: 0.0010
# Epoch 10/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 726ms/step - accuracy: 0.7126 - loss: 0.5632 - val_accuracy: 0.7393 - val_loss: 0.5427 - learning_rate: 0.0010
# Epoch 11/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 725ms/step - accuracy: 0.7076 - loss: 0.5694 - val_accuracy: 0.7147 - val_loss: 0.5685 - learning_rate: 0.0010
# Epoch 12/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 727ms/step - accuracy: 0.7111 - loss: 0.5666 - val_accuracy: 0.7458 - val_loss: 0.5289 - learning_rate: 0.0010
# Epoch 13/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 738ms/step - accuracy: 0.7207 - loss: 0.5519 - val_accuracy: 0.7303 - val_loss: 0.5375 - learning_rate: 0.0010
# Epoch 14/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 726ms/step - accuracy: 0.7124 - loss: 0.5645 - val_accuracy: 0.7138 - val_loss: 0.5715 - learning_rate: 0.0010
# Epoch 15/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 718ms/step - accuracy: 0.7107 - loss: 0.5656 - val_accuracy: 0.7415 - val_loss: 0.5287 - learning_rate: 0.0010
# Epoch 16/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 722ms/step - accuracy: 0.7207 - loss: 0.5507 - val_accuracy: 0.7122 - val_loss: 0.5634 - learning_rate: 0.0010
# Epoch 17/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 722ms/step - accuracy: 0.7184 - loss: 0.5568 - val_accuracy: 0.7433 - val_loss: 0.5270 - learning_rate: 0.0010
# Epoch 18/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.7134 - loss: 0.5605 - val_accuracy: 0.7380 - val_loss: 0.5341 - learning_rate: 0.0010
# Epoch 19/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 730ms/step - accuracy: 0.7149 - loss: 0.5556 - val_accuracy: 0.7000 - val_loss: 0.5865 - learning_rate: 0.0010
# Epoch 20/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 745ms/step - accuracy: 0.7121 - loss: 0.5613 - val_accuracy: 0.7442 - val_loss: 0.5289 - learning_rate: 0.0010
# Epoch 21/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 732ms/step - accuracy: 0.7214 - loss: 0.5508 - val_accuracy: 0.7458 - val_loss: 0.5233 - learning_rate: 0.0010
# Epoch 22/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 735ms/step - accuracy: 0.7235 - loss: 0.5466 - val_accuracy: 0.7377 - val_loss: 0.5290 - learning_rate: 0.0010
# Epoch 23/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 741ms/step - accuracy: 0.7192 - loss: 0.5535 - val_accuracy: 0.7408 - val_loss: 0.5247 - learning_rate: 0.0010
# Epoch 24/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 716ms/step - accuracy: 0.7145 - loss: 0.5615 - val_accuracy: 0.7318 - val_loss: 0.5385 - learning_rate: 0.0010
# Epoch 25/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 718ms/step - accuracy: 0.7191 - loss: 0.5524 - val_accuracy: 0.7107 - val_loss: 0.5593 - learning_rate: 0.0010
# Epoch 26/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - accuracy: 0.7144 - loss: 0.5542
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 715ms/step - accuracy: 0.7196 - loss: 0.5508 - val_accuracy: 0.7283 - val_loss: 0.5398 - learning_rate: 0.0010
# Epoch 27/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 731ms/step - accuracy: 0.7274 - loss: 0.5409 - val_accuracy: 0.7425 - val_loss: 0.5240 - learning_rate: 5.0000e-04
# Epoch 28/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 723ms/step - accuracy: 0.7278 - loss: 0.5370 - val_accuracy: 0.7405 - val_loss: 0.5272 - learning_rate: 5.0000e-04
# Epoch 29/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 729ms/step - accuracy: 0.7296 - loss: 0.5385 - val_accuracy: 0.7442 - val_loss: 0.5203 - learning_rate: 5.0000e-04
# Epoch 30/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 725ms/step - accuracy: 0.7299 - loss: 0.5357 - val_accuracy: 0.7455 - val_loss: 0.5197 - learning_rate: 5.0000e-04

# %% [markdown]
# ### Questions:
# - Describe the conditions that will lead the learning rate to be reduced, given our settings above.
# - Did the automated loss rate reduction we applied kick in during training? If yes, how many times was a reduction in loss rate applied?
# - Describe the conditions that will lead to early stopping, given our settings above.
# - Did early stopping kick in during training?

# %% [markdown]
# >The learning rate will be reduced when

# %% [markdown]
# Now that the model is trained, let's see the results on the test data. This will also take a little time, since evalaution in RNN's also happens sequentially. On my laptop, it took 2 minutes.

# %%
model_rnn.evaluate(x_test[...,np.newaxis], y_test)

# %% [markdown]
# ### Plot loss and accuracy

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results_rnn.history['loss'])
plt.plot(results_rnn.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(results_rnn.history['accuracy'])
plt.plot(results_rnn.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Questions:
# - Did the model converge?
# - Does the model have high bias, high variance, both, or neither?
# - How well does our model perform on the test data?
# - What would you suggest we try to improve the model performance?

# %% [markdown]
# # These two networks take longer to train. I suggest each group member train one of them in studio, and then you can compare your results.
# If you have extra time, you can go back and train the one you skipped.
#
#
# ## RNN 2: Bidirectional RNN

# %%
model_birnn = Sequential()
model_birnn.add(keras.Input(shape=(500, 1)))
model_birnn.add(Bidirectional(SimpleRNN(32, return_sequences=True, recurrent_initializer="glorot_uniform")))
#model_rnn.add(Bidirectional(SimpleRNN(64, return_sequences=True, recurrent_initializer="glorot_uniform")))
model_birnn.add(Bidirectional(SimpleRNN(10, return_sequences=True, recurrent_initializer="glorot_uniform")))
model_birnn.add(Flatten())
model_birnn.add(Dropout(0.3))
model_birnn.add(Dense(1, activation="sigmoid"))

model_birnn.summary()

# %% [markdown]
# ### Questions:
# - How many hidden layers does this model have?
# - How many free parameters?
# - Why does this model have more parameters than our first RNN model?

# %% [markdown]
# ### Compile and fit the model
#
# With more parameters, this model takes longer to train! We're training 4 RNNs here, not 2: for each RNN layer, we train one that moves forward through the sequence and one that moves backward through the sequence.
#
# For me, this network took ~1m per epoch to train, so about 30 mins in total.
#
# Feel free to have an project group check-in discussion while your networks train.

# %%
model_birnn.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.AdamW(1e-3, weight_decay=0.00008),
    metrics=['accuracy'])

# %%
results_birnn = model_birnn.fit(x_train[...,np.newaxis], y_train,
                    batch_size=1024,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1,
                    callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
                                 keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
                    )

# %% [markdown]
# ### Questions:
# - Did the automated loss rate reduction we applied kick in during training? If yes, how many times was a reduction in loss rate applied?
# - Did early stopping kick in during training?

# %% [markdown]
# Now that the model is trained, let's see the results on the test data. This will also take a little time, since evalaution in RNN's also happens sequentially. On my laptop, it took 2 minutes.

# %%
model_birnn.evaluate(x_test[...,np.newaxis], y_test)

# %% [markdown]
# ### Plot loss and accuracy

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results_birnn.history['loss'])
plt.plot(results_birnn.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(results_birnn.history['accuracy'])
plt.plot(results_birnn.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Questions:
# - Did the model converge?
# - Does the model have high bias, high variance, both, or neither?
# - How well does our model perform on the test data?
# - What would you suggest we try to improve the model performance?

# %% [markdown]
# ## RNN 3: LSTM
#
# This time, we'll try a relatively shallow uni-directional LSTM for comparison.

# %%
model_lstm = Sequential()
model_lstm.add(keras.Input(shape=(500, 1)))
model_lstm.add(LSTM(32, return_sequences=True, recurrent_initializer="glorot_uniform"))
#model_lstm.add(LSTM(64, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_lstm.add(LSTM(10, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_lstm.add(Flatten())
model_lstm.add(Dropout(0.3))
model_lstm.add(Dense(1, activation="sigmoid"))

model_lstm.summary()

# %% [markdown]
# ### Questions:
# - How many hidden layers does this model have?
# - How many free parameters?

# %% [markdown]
# #### LSTM Training

# %%
model_lstm.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.AdamW(1e-3, weight_decay=0.00008),
    metrics=['accuracy'])

# %% [markdown]
# More parameters mean longer training times: this one took ~1m per epoch on my laptop, about 28 minutes in total.
#
# Feel free to have an project group check-in discussion while your networks train.

# %%
results_lstm = model_lstm.fit(x_train[...,np.newaxis], y_train,
                    batch_size=1024,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1,
                    callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
                                 keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
                    )

# %% [markdown]
# ### Questions:
# - Did the automated loss rate reduction we applied kick in during training? If yes, how many times was a reduction in loss rate applied?
# - Did early stopping kick in during training?

# %%
model_lstm.evaluate(x_test[...,np.newaxis], y_test)

# %% [markdown]
# ### Plot loss and accuracy

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results_lstm.history['loss'])
plt.plot(results_lstm.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(results_lstm.history['accuracy'])
plt.plot(results_lstm.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Questions:
# - Did the model converge?
# - Does the model have high bias, high variance, both, or neither?
# - How well does our model perform on the test data?
# - What would you suggest we try to improve the model performance?

# %% [markdown]
# ### Conclusion Questions:
# - Based on the 3 networks, does adding more information about long-term correlations in the signal improve performance? Which networks should you compare to evaluate this? Connect your discussion to the cosmic ray signal shape you observed during the initial data exploration.
# - Based on the 3 networks, does adding more information about backwards-running correlations in the signal improve performance? Which networks should you compare to evaluate this? Connect your discussion to the cosmic ray signal shape you observed during the initial data exploration.
# - Can we conclude that for this task, LSTMs and bi-directionality won't ever help? Or are there other changes we should make before re-evaluating those questions? If so, describe the changes you'd suggest.

# %% [markdown]
# ### Acknowledgement Statement:

# %% [markdown]
# After that, you're done with studio for today! Upload your notebook to Gradescope, making sure to merge the written responses for all 3 RNNs into a single notebook, even if all 3 weren't trained in that notebook.

# %% [markdown]
# Now that the model is trained, let's see the results on the test data. This will also take a little time, since evalaution in RNN's also happens sequentially. On my laptop, it took 2 minutes.

# %%
model_rnn.evaluate(x_test[...,np.newaxis], y_test)

# %% [markdown]
# ### Plot loss and accuracy

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results_rnn.history['loss'])
plt.plot(results_rnn.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(results_rnn.history['accuracy'])
plt.plot(results_rnn.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Questions:
# - Did the model converge?
# - Does the model have high bias, high variance, both, or neither?
# - How well does our model perform on the test data?
# - What would you suggest we try to improve the model performance?

# %% [markdown]
# # These two networks take longer to train. I suggest each group member train one of them in studio, and then you can compare your results.
# If you have extra time, you can go back and train the one you skipped.
#
#
# ## RNN 2: Bidirectional RNN

# %%
model_birnn = Sequential()
model_birnn.add(keras.Input(shape=(500, 1)))
model_birnn.add(Bidirectional(SimpleRNN(32, return_sequences=True, recurrent_initializer="glorot_uniform")))
#model_rnn.add(Bidirectional(SimpleRNN(64, return_sequences=True, recurrent_initializer="glorot_uniform")))
model_birnn.add(Bidirectional(SimpleRNN(10, return_sequences=True, recurrent_initializer="glorot_uniform")))
model_birnn.add(Flatten())
model_birnn.add(Dropout(0.3))
model_birnn.add(Dense(1, activation="sigmoid"))

model_birnn.summary()

# %% [markdown]
# ### Questions:
# - How many hidden layers does this model have?
# - How many free parameters?
# - Why does this model have more parameters than our first RNN model?

# %% [markdown]
# ### Compile and fit the model
#
# With more parameters, this model takes longer to train! We're training 4 RNNs here, not 2: for each RNN layer, we train one that moves forward through the sequence and one that moves backward through the sequence.
#
# For me, this network took ~1m per epoch to train, so about 30 mins in total.
#
# Feel free to have an project group check-in discussion while your networks train.

# %%
model_birnn.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.AdamW(1e-3, weight_decay=0.00008),
    metrics=['accuracy'])

# %%
results_birnn = model_birnn.fit(x_train[...,np.newaxis], y_train,
                    batch_size=1024,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1,
                    callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
                                 keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
                    )

# %% [markdown]
# ### Questions:
# - Did the automated loss rate reduction we applied kick in during training? If yes, how many times was a reduction in loss rate applied?
# - Did early stopping kick in during training?

# %% [markdown]
# Now that the model is trained, let's see the results on the test data. This will also take a little time, since evalaution in RNN's also happens sequentially. On my laptop, it took 2 minutes.

# %%
model_birnn.evaluate(x_test[...,np.newaxis], y_test)

# %% [markdown]
# ### Plot loss and accuracy

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results_birnn.history['loss'])
plt.plot(results_birnn.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(results_birnn.history['accuracy'])
plt.plot(results_birnn.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Questions:
# - Did the model converge?
# - Does the model have high bias, high variance, both, or neither?
# - How well does our model perform on the test data?
# - What would you suggest we try to improve the model performance?

# %% [markdown]
# ## RNN 3: LSTM
#
# This time, we'll try a relatively shallow uni-directional LSTM for comparison.

# %%
model_lstm = Sequential()
model_lstm.add(keras.Input(shape=(500, 1)))
model_lstm.add(LSTM(32, return_sequences=True, recurrent_initializer="glorot_uniform"))
#model_lstm.add(LSTM(64, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_lstm.add(LSTM(10, return_sequences=True, recurrent_initializer="glorot_uniform"))
model_lstm.add(Flatten())
model_lstm.add(Dropout(0.3))
model_lstm.add(Dense(1, activation="sigmoid"))

model_lstm.summary()

# %% [markdown]
# ### Questions:
# - How many hidden layers does this model have?
# - How many free parameters?

# %% [markdown]
# #### LSTM Training

# %%
model_lstm.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.AdamW(1e-3, weight_decay=0.00008),
    metrics=['accuracy'])

# %% [markdown]
# More parameters mean longer training times: this one took ~1m per epoch on my laptop, about 28 minutes in total.
#
# Feel free to have an project group check-in discussion while your networks train.

# %%
results_lstm = model_lstm.fit(x_train[...,np.newaxis], y_train,
                    batch_size=1024,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1,
                    callbacks = [keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_delta=.0005, verbose=1, min_lr=1e-5),
                                 keras.callbacks.EarlyStopping(patience=10, min_delta=.0001, verbose=1)]
                    )

# %% [markdown]
# ### Questions:
# - Did the automated loss rate reduction we applied kick in during training? If yes, how many times was a reduction in loss rate applied?
# - Did early stopping kick in during training?

# %%
model_lstm.evaluate(x_test[...,np.newaxis], y_test)

# %% [markdown]
# ### Plot loss and accuracy

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results_lstm.history['loss'])
plt.plot(results_lstm.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(results_lstm.history['accuracy'])
plt.plot(results_lstm.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Questions:
# - Did the model converge?
# - Does the model have high bias, high variance, both, or neither?
# - How well does our model perform on the test data?
# - What would you suggest we try to improve the model performance?

# %% [markdown]
# ### Conclusion Questions:
# - Based on the 3 networks, does adding more information about long-term correlations in the signal improve performance? Which networks should you compare to evaluate this? Connect your discussion to the cosmic ray signal shape you observed during the initial data exploration.
# - Based on the 3 networks, does adding more information about backwards-running correlations in the signal improve performance? Which networks should you compare to evaluate this? Connect your discussion to the cosmic ray signal shape you observed during the initial data exploration.
# - Can we conclude that for this task, LSTMs and bi-directionality won't ever help? Or are there other changes we should make before re-evaluating those questions? If so, describe the changes you'd suggest.

# %% [markdown]
# ### Acknowledgement Statement:

# %% [markdown]
# After that, you're done with studio for today! Upload your notebook to Gradescope, making sure to merge the written responses for all 3 RNNs into a single notebook, even if all 3 weren't trained in that notebook.
